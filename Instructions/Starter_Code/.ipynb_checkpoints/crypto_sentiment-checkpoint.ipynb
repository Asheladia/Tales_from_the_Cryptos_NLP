# %%
import os
import pandas as pd
from newsapi import NewsApiClient
# %matplotlib inline

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Read your api key environment variable
api_key = 'c7825a5cbc5240d2a9245f8ec5ccc703'

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
btc_articles = newsapi.get_everything(q='bitcoin',
                                      language='en',
                                      sort_by='relevancy',
                                      )
btc_articles
# Out:
# {'status': 'ok',
#  'totalResults': 3614,
#  'articles': [{'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Jack Morse',
#    'title': 'J.K. Rowling is four cocktails in and talking trash about Bitcoin',
#    'description': "J.K. Rowling has been drinking a lot and you'd better believe she has some thoughts on Bitcoin.\nNoted TERF and author of The Cuckoo’s Calling, Rowling decided Friday was the perfect time to learn about the cryptocurrency Bitcoin. And so, like any celebrity wh…",
#    'url': 'https://mashable.com/article/jk-rowling-asked-twitter-about-bitcoin/',
#    'urlToImage': 'https://mondrian.mashable.com/2020%252F05%252F16%252Fed%252F65127486efd14faea068927124f3b1ee.253ab.jpg%252F1200x630.jpg?signature=XjJ4aqKaX56MW5k29Zn1ygz0Evc=',
#    'publishedAt': '2020-05-16T00:34:00Z',
#    'content': "J.K. Rowling has been drinking a lot and you'd better believe she has some thoughts on Bitcoin.\r\nNotedTERF and author of The Cuckoos Calling, Rowlingdecided Friday was the perfect time to learn about… [+2124 chars]"},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Shoshana Wodinsky',
#    'title': "Teenager Accused of Leading Ring of 'Evil Geniuses' on $24 Million 'Cybercrime Spree'",
#    'description': 'Yesterday, the prominent bitcoin investor Michael Terpin announced that he’d filed suit against the ringleader of a “SIM swap gang” that he’d been chasing down since 2018, following the theft of roughly a collective $24 million in bitcoin from his digital wal…',
#    'url': 'https://gizmodo.com/teenager-accused-of-leading-ring-of-evil-geniuses-on-2-1843348642',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/zmk5zwfltc237e2lutab.jpg',
#    'publishedAt': '2020-05-08T22:21:00Z',
#    'content': 'Yesterday, the prominent bitcoin investor Michael Terpin announced that hed filed suit against the ringleader of a SIM swap gang that hed been chasing down since 2018, following the theft of roughly … [+2243 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Stan Schroeder',
#    'title': 'A massive Bitcoin event is coming next week. Here’s what you need to know.',
#    'description': 'Early next week, Bitcoin is about to experience its third-ever halving, a hugely important event that could shift the balance of power within the network. Historically the event, also called the halvening, drove the price of Bitcoin up, especially in the long…',
#    'url': 'https://mashable.com/article/bitcoin-halving-2020/',
#    'urlToImage': 'https://mondrian.mashable.com/2020%252F05%252F08%252Fa8%252Fc07c26da4a034343ac4f3658790fbf1b.f03d7.png%252F1200x630.png?signature=arGT86ntGpF3sw7-o8Hqu_k4wLw=',
#    'publishedAt': '2020-05-08T09:00:00Z',
#    'content': 'Early next week, Bitcoin is about to experience its third-ever halving, a hugely important event that could shift the balance of power within the network. Historically the event, also called the halv… [+7424 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Alex Wilhelm',
#    'title': 'FalconX raises $17M to power its crypto trading service',
#    'description': 'Over the last few weeks all eyes in the crypto world have been glued to the halvening, a nigh-religious moment in the blockchain realm. Every once in a while, the amount of new bitcoin mined — distributed to miners, the folks with fleets of computers powering…',
#    'url': 'http://techcrunch.com/2020/05/13/falconx-raises-17m-to-power-its-crypto-trading-service/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/04/bitcoin-bitfinex.jpg?w=750',
#    'publishedAt': '2020-05-13T15:46:38Z',
#    'content': 'Over the last few weeks all eyes in the crypto world have been glued to the halvening, a nigh-religious moment in the blockchain realm. Every once in a while, the amount of new bitcoin mined — distri… [+4849 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'David Murphy',
#    'title': 'How to Buy a Burner Phone',
#    'description': 'If you’re planning to do some protesting and you don’t want to risk your expensive smartphone in the process—or you simply want to keep yourself as anonymous as possible while you’re out—consider buying a burner phone. Yes, it’ll cost a little cash, but picki…',
#    'url': 'https://lifehacker.com/how-to-buy-a-burner-phone-1843905326',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/qtukpcqooat11zbahjwg.jpg',
#    'publishedAt': '2020-06-04T19:00:00Z',
#    'content': 'If youre planning to do some protesting and you dont want to risk your expensive smartphone in the processor you simply want to keep yourself as anonymous as possible while youre outconsider buying a… [+5568 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'BeauHD',
#    'title': 'It Happened: Bitcoin Just Experienced Third Halving In Its History',
#    'description': "The most anticipated cryptocurrency event of 2020, Bitcoin's (BTC) third halving, has just taken effect. Occurring only once every four years, the latest Bitcoin mining block reward halving just reduced the Bitcoin block reward from 12.5 BTC to 6.25 BTC. Coin…",
#    'url': 'https://news.slashdot.org/story/20/05/11/2031221/it-happened-bitcoin-just-experienced-third-halving-in-its-history',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2020-05-11T20:45:00Z',
#    'content': 'Since the first Bitcoin block was generated back in 2009, there have been three halving events. Taking place once every 210,000 blocks mined, or approximately once every four years, a Bitcoin halving… [+1044 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Matthew Fox',
#    'title': 'The crypto market grows by $13 billion as bitcoin breaks the $10,000 threshold for the first time since February (BTC)',
#    'description': '<ul>\n<li>The cryptocurrency market added $13 billion in value over the past day as bitcoin jumped more than 6% Thursday evening.</li>\n<li>Bitcoin has rallied more than 100% from its March 16 low and has eclipsed $10,000 for the first time since February.</li>…',
#    'url': 'https://www.businessinsider.com/bitcoin-price-crypto-market-grows-billions-breaks-threshold-value-total-2020-5',
#    'urlToImage': 'https://i.insider.com/5eb557c9204ad34d406c1c17?width=1200&format=jpeg',
#    'publishedAt': '2020-05-08T14:19:03Z',
#    'content': '<ul><li>The cryptocurrency market added $13 billion in value over the past day as bitcoin jumped more than 6% Thursday evening.</li><li>Bitcoin has rallied more than 100% from its March 16 low and ha… [+3575 chars]'},
#   {'source': {'id': None, 'name': 'YouTube'},
#    'author': None,
#    'title': 'The halving is here: Will it boost bitcoin prices? - CNBC Television',
#    'description': "<ol><li>The halving is here: Will it boost bitcoin prices?\xa0\xa0CNBC Television\r\n</li><li>The 'halving' is nigh and bitcoin is losing ground\xa0\xa0Aljazeera.com\r\n</li><li>What the third bitcoin halving means for investors\xa0\xa0Yahoo Finance\r\n</li><li>Bitcoin 'halving': Wh…",
#    'url': 'https://www.youtube.com/watch?v=GYoegTF5Qks',
#    'urlToImage': 'https://i.ytimg.com/vi/GYoegTF5Qks/hqdefault.jpg',
#    'publishedAt': '2020-05-11T22:16:22Z',
#    'content': None},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Matthew Fox',
#    'title': "Goldman Sachs lists 5 reasons why bitcoin is 'not an asset class', nor 'a suitable investment' (BTCUSD)",
#    'description': '<ul>\n<li>Goldman Sachs gave five reasons why it thinks bitcoin is "not an asset class" nor "a suitable investment" in a presentation Wednesday morning.</li>\n<li>Goldman observed that the cryptocurrency infrastructure is still young and susceptible to hacking …',
#    'url': 'https://markets.businessinsider.com/currencies/news/bitcoin-goldman-lists-reasons-why-not-asset-class-suitable-investment-2020-5-1029248469',
#    'urlToImage': 'https://images.markets.businessinsider.com/image/5ecfadc8aee6a861af18ac14-2400/2020-05-11t214412z1lynxmpeg4a25artroptp4crypto-currencies-bitcoin-halving.jpg',
#    'publishedAt': '2020-05-28T14:18:38Z',
#    'content': 'Reuters\r\n<ul><li>Goldman Sachs gave five reasons why it thinks bitcoin is "not an asset class" nor "a suitable investment" in a presentation Wednesday morning.</li><li>Goldman observed that the crypt… [+3412 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Matthew Fox',
#    'title': "'Get on the train': Famed investor Michael Novogratz says bitcoin will soon break the $10,000 threshold as US turmoil spreads (BTCUSD)",
#    'description': '<ul>\n<li>Famed investor Michael Novogratz tweeted on Monday that bitcoin will soon take out the $10,000 resistance level, telling his followers, "Get on the train."</li>\n<li>Novogratz said that turmoil spreading throughout the US only adds to the bitcoin narr…',
#    'url': 'https://www.businessinsider.com/bitcoin-price-novogratz-forecast-says-break-level-us-turmoil-spreads-2020-6',
#    'urlToImage': 'https://i.insider.com/5ed65008f0f4195f641c1656?width=1200&format=jpeg',
#    'publishedAt': '2020-06-02T14:19:53Z',
#    'content': '<ul><li>Famed investor Michael Novogratz tweeted on Monday that bitcoin will soon take out the $10,000 resistance level, telling his followers, "Get on the train."</li><li>Novogratz said that turmoil… [+2757 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin continues downtrend with 5% loss in one day’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Satoshi Nakamoto used to say: Time to lear…',
#    'url': 'https://thenextweb.com/hardfork/2020/05/25/satoshi-nakaboto-bitcoin-continues-downtrend-with-5-loss-in-one-day/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-05-25T09:46:32Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3004 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'BeauHD',
#    'title': 'JPMorgan Extends Banking Services To Bitcoin Exchanges',
#    'description': 'According to The Wall Street Journal, JPMorgan Chase has taken on Coinbase and Gemini Trust as banking customers (Warning: source paywalled; alternative source) -- "the first time the bank has accepted clients from the cryptocurrency industry." From the repor…',
#    'url': 'https://news.slashdot.org/story/20/05/13/2213222/jpmorgan-extends-banking-services-to-bitcoin-exchanges',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2020-05-14T02:02:00Z',
#    'content': 'The move is the latest in a string of positive developments for bitcoin and another sign that Wall Street is becoming more comfortable with the business of cryptocurrencies. Coinbase, founded in 2012… [+1067 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Visa approves launch of crypto debit card in Europe’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Locke used to say: Let’s add the milk of d…',
#    'url': 'https://thenextweb.com/hardfork/2020/05/26/satoshi-nakaboto-visa-approves-launch-of-crypto-debit-card-in-europe/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-05-26T10:03:18Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the … [+3041 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Oliver Isaacs',
#    'title': '8 Reasons Why This Could Be the Time to Take Bitcoin Seriously',
#    'description': 'You had me at inflation-resistant, says this expert.',
#    'url': 'https://www.entrepreneur.com/article/348168',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1589913472-GettyImages-1174079406.jpg',
#    'publishedAt': '2020-05-22T18:00:00Z',
#    'content': 'Opinions expressed by Entrepreneur contributors are their own.\r\nDespite recent price volatility\xa0and global macroeconomic uncertainty, 2020 is a big year for Bitcoin. Although a large number of busine… [+6168 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin close to $10,000’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Schopenhauer used to say: I got the horses…',
#    'url': 'https://thenextweb.com/hardfork/2020/05/08/satoshi-nakaboto-bitcoin-close-to-10000/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-05-08T09:39:05Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3080 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin is a bad investment according to Goldman Sachs’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Baudriallard used to say: Let’s get this b…',
#    'url': 'https://thenextweb.com/hardfork/2020/05/28/satoshi-nakaboto-bitcoin-is-a-bad-investment-according-to-goldman-sachs/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-05-28T10:14:33Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3009 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘S&P 500 outperformed Bitcoin over the past year’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Aristotle used to say: Let’s get it! Bitco…',
#    'url': 'https://thenextweb.com/hardfork/2020/05/27/satoshi-nakaboto-sp-500-outperformed-bitcoin-over-the-past-year/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-05-27T10:28:15Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2941 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin whale moves $400M, pays $2.50 fee’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Isaac Newton used to say: Intelligence is …',
#    'url': 'https://thenextweb.com/hardfork/2020/05/22/satoshi-nakaboto-bitcoin-whale-moves-400m-pays-2-50-fee/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-05-22T09:36:55Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2953 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin plummets almost $700 in an hour, back below $10K’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Stephen Hawking used to say: To infinity, …',
#    'url': 'https://thenextweb.com/hardfork/2020/06/03/satoshi-nakaboto-bitcoin-plummets-almost-700-in-an-hour-back-below-10k/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-06-03T08:30:22Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3328 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘JPMorgan now offers banking services to Bitcoin exchanges’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As de Beauvoir used to say: The long and wind…',
#    'url': 'https://thenextweb.com/hardfork/2020/05/13/satoshi-nakaboto-jpmorgan-now-offers-banking-services-to-bitcoin-exchanges/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-05-13T09:56:47Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3065 chars]'}]}

# %%
# Fetch the Ethereum news articles
eth_articles = newsapi.get_everything(q='ethereum',
                                      language='en',
                                      sort_by='relevancy',
                                      )
eth_articles
# Out:
# {'status': 'ok',
#  'totalResults': 894,
#  'articles': [{'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Henry Pickavet',
#    'title': 'Crypto Startup School: How to scale companies using crypto',
#    'description': 'In week two of a16z’s Crypto Startup School, three company-builders provide real-world advice on using the qualities of crypto to create new business models and networks.',
#    'url': 'http://techcrunch.com/2020/05/20/crypto-startup-school-how-to-scale-companies-using-crypto/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/05/GettyImages-1170889477.jpg?w=711',
#    'publishedAt': '2020-05-20T19:00:17Z',
#    'content': 'Editors note:Andreessen Horowitzs Crypto Startup School brought together 45 participants from around the U.S. and overseas in a seven-week course to learn how to build crypto companies. Andreessen Ho… [+2503 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Lucas Matney',
#    'title': 'Decentralized identity management platform Magic launches from stealth with $4M',
#    'description': 'For developers looking to quickly build identity management into their platforms, the most readily available options don’t stray far from the internet’s biggest, most data-hungry platforms. Magic, a small SF startup building a decentralized blockchain-based i…',
#    'url': 'http://techcrunch.com/2020/06/03/decentralized-identity-management-platform-magic-launches-from-stealth-with-4m/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/06/Magic-Team-Photo-ETHDenver-2020.jpg?w=600',
#    'publishedAt': '2020-06-03T22:55:42Z',
#    'content': 'For developers looking to quickly build identity management into their platforms, the most readily available options don’t stray far from the internet’s biggest, most data-hungry platforms.\r\nMagic, a… [+2450 chars]'},
#   {'source': {'id': None, 'name': 'Medium'},
#    'author': 'Alex Roan',
#    'title': 'Web3 JavaScript Functions for Ethereum DApps',
#    'description': 'Web3 bridges the gap between the traditional internet and the Ethereum blockchain. It enables users to interact with your DApp through a browser. When using JavaScript for your front end, knowing the…',
#    'url': 'https://medium.com/better-programming/the-top-5-web3-javascript-functions-for-ethereum-dapps-7bc108bfd37',
#    'urlToImage': 'https://miro.medium.com/max/1200/0*jldz3o40zYbFa7WV',
#    'publishedAt': '2020-05-14T11:56:46Z',
#    'content': 'Use this to send Ether from one account to another or a smart contract address. It requires a few parameters depending on the transaction. Possible parameters include from, to, value, gas, and more.\r… [+206 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'EditorDavid',
#    'title': "'FOSS Responders' Want to Help Open-Source Groups Survive",
#    'description': '"Thanks to the coronavirus, technology events have been canceled left and right," writes ZDNet. "This, in turn, is damaging the finances of companies and groups that depend on these events."\n\nSome open-source groups, such as The Linux Foundation, can deal wit…',
#    'url': 'https://news.slashdot.org/story/20/05/23/2351224/foss-responders-want-to-help-open-source-groups-survive',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/opensource_64.png',
#    'publishedAt': '2020-05-24T18:34:00Z',
#    'content': "Some open-source groups, such as The Linux Foundation, can deal with it. Others aren't so fortunate. Some, such as Drupal Foundation, the Open Source Initiative (OSI), Open Source Matters (Joomla), a… [+1202 chars]"},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Shailee Adinolfi',
#    'title': "The US Could Deliver Stimulus Checks Faster—With Tech's Help",
#    'description': 'The federal government desperately needs to take cues from global humanitarian agencies that have developed quick and secure payment tools.',
#    'url': 'https://www.wired.com/story/opinion-the-us-could-deliver-stimulus-checks-faster-with-techs-help/',
#    'urlToImage': 'https://media.wired.com/photos/5eb9e08088ead7be95a5c687/191:100/w_1280,c_limit/OpEd-Money-123496124.jpg',
#    'publishedAt': '2020-05-12T13:00:00Z',
#    'content': 'With unemployment surging and businesses struggling under lockdown, millions of Americans are relying on the extra benefits payments issued under the $2 trillion dollar Coronavirus Aid, Relief and Ec… [+5094 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Alex Wilhelm',
#    'title': 'FalconX raises $17M to power its crypto trading service',
#    'description': 'Over the last few weeks all eyes in the crypto world have been glued to the halvening, a nigh-religious moment in the blockchain realm. Every once in a while, the amount of new bitcoin mined — distributed to miners, the folks with fleets of computers powering…',
#    'url': 'http://techcrunch.com/2020/05/13/falconx-raises-17m-to-power-its-crypto-trading-service/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/04/bitcoin-bitfinex.jpg?w=750',
#    'publishedAt': '2020-05-13T15:46:38Z',
#    'content': 'Over the last few weeks all eyes in the crypto world have been glued to the halvening, a nigh-religious moment in the blockchain realm. Every once in a while, the amount of new bitcoin mined — distri… [+4849 chars]'},
#   {'source': {'id': None, 'name': 'Avc.com'},
#    'author': 'Fred Wilson',
#    'title': 'r/CryptoCurrency Moons',
#    'description': 'We have been looking for ways in which crypto assets can go mainstream. Our interest and investment in Dapper’s crypto games is an effort in that area. So is our involvement in the Libra project. We also have been involved in legacy mobile and web apps that h…',
#    'url': 'https://avc.com/2020/05/r-cryptocurrency-moons/',
#    'urlToImage': None,
#    'publishedAt': '2020-05-14T18:18:38Z',
#    'content': 'We have been looking for ways in which crypto assets can go mainstream. Our interest and investment in Dapper’s crypto games is an effort in that area. So is our involvement in the Libra project. \r\nW… [+1743 chars]'},
#   {'source': {'id': None, 'name': 'Techmeme.com'},
#    'author': None,
#    'title': 'TD Ameritrade-backed ErisX launches the first Ethereum futures trading platform in the US authorized by regulators (Alexander Behrens/Decrypt)',
#    'description': 'Alexander Behrens / Decrypt:\nTD Ameritrade-backed ErisX launches the first Ethereum futures trading platform in the US authorized by regulators\xa0 —\xa0 Ethereum has taken another big step into the regulated financial world.\xa0 —\xa0 ErisX, a US-based digital asset tra…',
#    'url': 'https://www.techmeme.com/200511/p24',
#    'urlToImage': 'https://cdn.decrypt.co/resize/1024/height/512/wp-content/uploads/2020/05/ethereum-futures-trading-cftc-erisx-gID_6.jpg',
#    'publishedAt': '2020-05-11T21:55:01Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Mozilla.community'},
#    'author': None,
#    'title': 'Mozilla’s Fix-the-Internet Incubator',
#    'description': 'Help Mozilla build a new generation of startups, products, services, and projects that deliver on the full promise of the internet.',
#    'url': 'https://builders.mozilla.community',
#    'urlToImage': 'https://builders.mozilla.community/assets/img/share.jpg',
#    'publishedAt': '2020-05-26T13:23:54Z',
#    'content': 'Back in March, we put out our call for ideas to "fix-the-internet". 1500 of you showed up and well over a hundred projects are now underway. Now we\'re launching our v2: the Mozilla Builders Incubator… [+469 chars]'},
#   {'source': {'id': None, 'name': 'Techmeme.com'},
#    'author': None,
#    'title': 'Reddit is beta testing two Ethereum-based tokens for users to earn rewards for contributing content to subreddits /r/Cryptocurrency and /r/FortniteBR (Celia Wan/The Block)',
#    'description': 'Celia Wan / The Block:\nReddit is beta testing two Ethereum-based tokens for users to earn rewards for contributing content to subreddits /r/Cryptocurrency and /r/FortniteBR\xa0 —\xa0 Reddit, the popular online forum, is beta testing two Ethereum-based tokens for us…',
#    'url': 'https://www.techmeme.com/200514/p2',
#    'urlToImage': 'https://www.tbstat.com/wp/uploads/2020/05/reddit-1063x675.jpg',
#    'publishedAt': '2020-05-14T06:55:02Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Techmeme.com'},
#    'author': None,
#    'title': 'ConsenSys has helped North American Collegiate League build an Ethereum-based service to make reporting smoother, automate payments for its esports tournaments (Jeff Benson/Decrypt)',
#    'description': 'Jeff Benson / Decrypt:\nConsenSys has helped North American Collegiate League build an Ethereum-based service to make reporting smoother, automate payments for its esports tournaments\xa0 —\xa0 ConsenSys has partnered with the North American Collegiate League to bri…',
#    'url': 'https://www.techmeme.com/200601/p23',
#    'urlToImage': 'https://cdn.decrypt.co/resize/1024/height/512/wp-content/uploads/2020/06/Excited-gamer-gID_2.jpg',
#    'publishedAt': '2020-06-02T00:10:04Z',
#    'content': None},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Matthew Fox',
#    'title': 'The crypto market grows by $13 billion as bitcoin breaks the $10,000 threshold for the first time since February (BTC)',
#    'description': '<ul>\n<li>The cryptocurrency market added $13 billion in value over the past day as bitcoin jumped more than 6% Thursday evening.</li>\n<li>Bitcoin has rallied more than 100% from its March 16 low and has eclipsed $10,000 for the first time since February.</li>…',
#    'url': 'https://www.businessinsider.com/bitcoin-price-crypto-market-grows-billions-breaks-threshold-value-total-2020-5',
#    'urlToImage': 'https://i.insider.com/5eb557c9204ad34d406c1c17?width=1200&format=jpeg',
#    'publishedAt': '2020-05-08T14:19:03Z',
#    'content': '<ul><li>The cryptocurrency market added $13 billion in value over the past day as bitcoin jumped more than 6% Thursday evening.</li><li>Bitcoin has rallied more than 100% from its March 16 low and ha… [+3575 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin on its way back to $10,000’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Descartes used to say: Let’s get this brea…',
#    'url': 'https://thenextweb.com/hardfork/2020/06/05/satoshi-nakaboto-bitcoin-on-its-way-back-to-10000/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-06-05T10:17:20Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3070 chars]'},
#   {'source': {'id': None, 'name': 'ReadWrite'},
#    'author': 'Waqas Dogar',
#    'title': '10 Ways to Skyrocket Business Growth Using Blockchain Technology',
#    'description': 'Blockchain technology is cementing its position in the business marketplace to help you get more customers. Gratefully, the first thing that blockchain will help with is better security. But it’s going to take some time for the business community to adopt blo…',
#    'url': 'https://readwrite.com/2020/06/03/10-ways-to-skyrocket-business-growth-using-blockchain-technology/',
#    'urlToImage': 'https://images.readwrite.com/wp-content/uploads/2020/04/Business-Growth-Using-Blockchain-Technology.jpg',
#    'publishedAt': '2020-06-03T18:00:47Z',
#    'content': 'Blockchain technology is cementing its position in the business marketplace to help you get more customers. Gratefully, the first thing that blockchain will help with is better security. But it’s goi… [+9561 chars]'},
#   {'source': {'id': None, 'name': 'Techmeme.com'},
#    'author': None,
#    'title': 'There is only around $8M in bitcoin on the Lightning Network about two years after launching in beta, less than the ~$11.5M locked up in Ethereum wallet dapps (Liam Frost/Decrypt)',
#    'description': "Liam Frost / Decrypt:\nThere is only around $8M in bitcoin on the Lightning Network about two years after launching in beta, less than the ~$11.5M locked up in Ethereum wallet dapps\xa0 —\xa0 Ethereum's decentralized finance applications have attracted more BTC than…",
#    'url': 'https://www.techmeme.com/200511/p27',
#    'urlToImage': 'https://cdn.decrypt.co/resize/1024/height/512/wp-content/uploads/2020/05/shutterstock_6612713981-gID_1.jpg',
#    'publishedAt': '2020-05-12T00:10:01Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Jennifer Spencer',
#    'title': '4 Fun Ways for Millennials to Dip Their Toes Into Investing',
#    'description': 'Convertible loans, DIY platforms and methods for building that nest egg today.',
#    'url': 'https://www.entrepreneur.com/article/350629',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1589489340-GettyImages-1150767833.jpg',
#    'publishedAt': '2020-05-18T13:30:00Z',
#    'content': 'Opinions expressed by Entrepreneur contributors are their own.\r\nCalling all millennials:\xa0How much of your money is in equity\xa0or invested somewhere? Sure, there may be a savings account in a mutual fu… [+4116 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Oliver Isaacs',
#    'title': '8 Reasons Why This Could Be the Time to Take Bitcoin Seriously',
#    'description': 'You had me at inflation-resistant, says this expert.',
#    'url': 'https://www.entrepreneur.com/article/348168',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1589913472-GettyImages-1174079406.jpg',
#    'publishedAt': '2020-05-22T18:00:00Z',
#    'content': 'Opinions expressed by Entrepreneur contributors are their own.\r\nDespite recent price volatility\xa0and global macroeconomic uncertainty, 2020 is a big year for Bitcoin. Although a large number of busine… [+6168 chars]'},
#   {'source': {'id': None, 'name': 'PocketNow'},
#    'author': 'Lee Kelly',
#    'title': 'Reddit tests its own cryptocurrency to reward users for boosting engagement',
#    'description': "Reddit's cryptocurrency is called Community Points and it runs on the Ethereum network. \nThe post Reddit tests its own cryptocurrency to reward users for boosting engagement appeared first on Pocketnow.",
#    'url': 'https://pocketnow.com/reddit-tests-its-own-cryptocurrency-to-reward-users-for-boosting-engagement',
#    'urlToImage': 'https://pocketnow.com/wp/../files/2020/05/redditcoin.jpg',
#    'publishedAt': '2020-05-17T18:26:18Z',
#    'content': 'After Facebook and Telegram, Reddit is the next major social media platform to venture into the world of cryptocurrencies. The self-proclaimed “front page of the internet” is testing a cryptocurrency… [+1413 chars]'},
#   {'source': {'id': None, 'name': 'Web3.coach'},
#    'author': 'Lukas Lukac',
#    'title': 'Why I left Trivago to become a blockchain developer',
#    'description': "Because I get to program innovative and creative solutions for many unresolved challenges our society faces today. The blockchain ecosystem is a programmer's dream.",
#    'url': 'https://web3.coach/blockchain-programming-career',
#    'urlToImage': 'https://web3coach-public.s3.eu-central-1.amazonaws.com/blog/blockchain_career.png',
#    'publishedAt': '2020-05-13T12:59:46Z',
#    'content': "Why?\r\nBecause I get to program innovative and creative solutions for many unresolved challenges our society faces today.\r\nBecause I am relatively young (27) and I don't want to compete for Java posit… [+8262 chars]"},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Jason Brett, Contributor, Jason Brett, Contributorhttps://www.forbes.com/sites/jasonbrett/',
#    'title': 'Federal Endorses Ethereum-Backed Alternative To Libor',
#    'description': 'Federal Reserve Board Chairman Jerome H. Powell has provided a statement regarding the suitability of AMERIBOR as a replacement to LIBOR.',
#    'url': 'https://www.forbes.com/sites/jasonbrett/2020/06/03/federal-endorses-ethereum-backed-alternative-to-libor/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5ed7e3a478fc0b0007ea7bb5%2F0x0.jpg%3FcropX1%3D298%26cropX2%3D6192%26cropY1%3D0%26cropY2%3D3315',
#    'publishedAt': '2020-06-03T21:42:29Z',
#    'content': 'Federal Reserve Board Chairman Jerome H. Powell provided a statement on May 28, 2020, regarding the suitability of AMERIBOR as a replacement to LIBOR. AMERIBOR uses a permissioned version of Ethereum… [+6230 chars]'}]}

# %%
# Create the Bitcoin sentiment scores DataFrame

# %%
def get_sentiment_score(article, based_on):
    sentiments = []
    for article in article["articles"]:
        try:
            text = article[based_on]
            date = article["publishedAt"][:10]
            sentiment = analyzer.polarity_scores(text)
            compound = sentiment["compound"]
            pos = sentiment["pos"]
            neu = sentiment["neu"]
            neg = sentiment["neg"]
            sentiments.append({
                based_on : text,
                "Compound": compound,
                "Negative": neg,
                "Neutral": neu,
                "Positive": pos
            })
        except AttributeError:
            pass
    # Create DataFrame
    df = pd.DataFrame(sentiments)
    return df

# %%
btc_sentiment_df = get_sentiment_score(btc_articles, 'content')
btc_sentiment_df
# Out:
#     Compound  Negative  Neutral  Positive  \
# 0     0.7650     0.000    0.829     0.171
# 1     0.3182     0.000    0.933     0.067
# 2     0.2716     0.000    0.939     0.061
# 3     0.0000     0.000    1.000     0.000
# 4    -0.3464     0.134    0.819     0.046
# 5    -0.5859     0.134    0.866     0.000
# 6     0.0772     0.058    0.877     0.066
# 7    -0.2755     0.070    0.930     0.000
# 8     0.0000     0.000    1.000     0.000
# 9     0.5070     0.000    0.910     0.090
# 10    0.8016     0.000    0.812     0.188
# 11    0.5070     0.000    0.910     0.090
# 12   -0.2732     0.078    0.879     0.042
# 13    0.5070     0.000    0.910     0.090
# 14    0.5070     0.000    0.910     0.090
# 15    0.5070     0.000    0.910     0.090
# 16    0.5070     0.000    0.910     0.090
# 17    0.5070     0.000    0.910     0.090
# 18    0.5070     0.000    0.910     0.090
#
#                                               content
# 0   J.K. Rowling has been drinking a lot and you'd...
# 1   Yesterday, the prominent bitcoin investor Mich...
# 2   Early next week, Bitcoin is about to experienc...
# 3   Over the last few weeks all eyes in the crypto...
# 4   If youre planning to do some protesting and yo...
# 5   Since the first Bitcoin block was generated ba...
# 6   <ul><li>The cryptocurrency market added $13 bi...
# 7   Reuters\r\n<ul><li>Goldman Sachs gave five rea...
# 8   <ul><li>Famed investor Michael Novogratz tweet...
# 9   Our robot colleague Satoshi Nakaboto writes ab...
# 10  The move is the latest in a string of positive...
# 11  Our robot colleague Satoshi Nakaboto writes ab...
# 12  Opinions expressed by Entrepreneur contributor...
# 13  Our robot colleague Satoshi Nakaboto writes ab...
# 14  Our robot colleague Satoshi Nakaboto writes ab...
# 15  Our robot colleague Satoshi Nakaboto writes ab...
# 16  Our robot colleague Satoshi Nakaboto writes ab...
# 17  Our robot colleague Satoshi Nakaboto writes ab...
# 18  Our robot colleague Satoshi Nakaboto writes ab...

# %%
# Create the ethereum sentiment scores DataFrame
eth_sentiment_df = get_sentiment_score(eth_articles, 'content')
eth_sentiment_df
# Out:
#     Compound  Negative  Neutral  Positive  \
# 0     0.0000     0.000    1.000     0.000
# 1     0.0000     0.000    1.000     0.000
# 2     0.6249     0.000    0.859     0.141
# 3    -0.4457     0.086    0.882     0.031
# 4     0.0000     0.148    0.703     0.148
# 5     0.0000     0.000    1.000     0.000
# 6     0.5719     0.000    0.885     0.115
# 7     0.2732     0.000    0.943     0.057
# 8     0.0772     0.058    0.877     0.066
# 9     0.5070     0.000    0.910     0.090
# 10    0.9198     0.000    0.665     0.335
# 11    0.3182     0.000    0.933     0.067
# 12   -0.2732     0.078    0.879     0.042
# 13    0.0000     0.000    1.000     0.000
# 14    0.7634     0.033    0.729     0.238
# 15    0.0000     0.000    1.000     0.000
#
#                                               content
# 0   Editors note:Andreessen Horowitzs Crypto Start...
# 1   For developers looking to quickly build identi...
# 2   Use this to send Ether from one account to ano...
# 3   Some open-source groups, such as The Linux Fou...
# 4   With unemployment surging and businesses strug...
# 5   Over the last few weeks all eyes in the crypto...
# 6   We have been looking for ways in which crypto ...
# 7   Back in March, we put out our call for ideas t...
# 8   <ul><li>The cryptocurrency market added $13 bi...
# 9   Our robot colleague Satoshi Nakaboto writes ab...
# 10  Blockchain technology is cementing its positio...
# 11  Opinions expressed by Entrepreneur contributor...
# 12  Opinions expressed by Entrepreneur contributor...
# 13  After Facebook and Telegram, Reddit is the nex...
# 14  Why?\r\nBecause I get to program innovative an...
# 15  Federal Reserve Board Chairman Jerome H. Powel...

# %%
# Describe the Bitcoin Sentiment
btc_sentiment_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  19.000000  19.000000  19.000000  19.000000
# mean    0.253084   0.024947   0.903368   0.071632
# std     0.398747   0.046209   0.050314   0.051823
# min    -0.585900   0.000000   0.812000   0.000000
# 25%     0.000000   0.000000   0.878000   0.044000
# 50%     0.507000   0.000000   0.910000   0.090000
# 75%     0.507000   0.029000   0.920000   0.090000
# max     0.801600   0.134000   1.000000   0.188000

# %%
# Describe the Ethereum Sentiment\
eth_sentiment_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  16.000000  16.000000  16.000000  16.000000
# mean    0.208544   0.025188   0.891562   0.083125
# std     0.379712   0.044487   0.109049   0.095304
# min    -0.445700   0.000000   0.665000   0.000000
# 25%     0.000000   0.000000   0.872500   0.000000
# 50%     0.038600   0.000000   0.897500   0.061500
# 75%     0.523225   0.039250   1.000000   0.121500
# max     0.919800   0.148000   1.000000   0.335000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum - 0.919800
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum - 0.335

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Expand the default stopwords list if necessary
lemmatizer = WordNetLemmatizer()
sw = set(stopwords.words('english'))

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    # Remove the punctuation
    regex = re.compile("[^a-zA-Z0-9 ]")
    re_clean = regex.sub('', text)
    
    # Create a list of the words
    words = word_tokenize(re_clean.lower())
   
        
    # Convert the words to lowercase
    words = [word for word in words if word not in sw]
           
    # Lemmatize Words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
    return lem

tokenizer(btc_sentiment_df.iloc[0]['content'])
# Out:
# ['jk',
#  'rowling',
#  'drinking',
#  'lot',
#  'youd',
#  'better',
#  'believe',
#  'thought',
#  'bitcoinnotedterf',
#  'author',
#  'cuckoo',
#  'calling',
#  'rowlingdecided',
#  'friday',
#  'perfect',
#  'time',
#  'learn',
#  '2124',
#  'char']

# %%
# Create a new tokens column for bitcoin
btc_sentiment_df['tokens'] = btc_sentiment_df['content'].apply(tokenizer)
btc_sentiment_df
# Out:
#     Compound  Negative  Neutral  Positive  \
# 0     0.7650     0.000    0.829     0.171
# 1     0.3182     0.000    0.933     0.067
# 2     0.2716     0.000    0.939     0.061
# 3     0.0000     0.000    1.000     0.000
# 4    -0.3464     0.134    0.819     0.046
# 5    -0.5859     0.134    0.866     0.000
# 6     0.0772     0.058    0.877     0.066
# 7    -0.2755     0.070    0.930     0.000
# 8     0.0000     0.000    1.000     0.000
# 9     0.5070     0.000    0.910     0.090
# 10    0.8016     0.000    0.812     0.188
# 11    0.5070     0.000    0.910     0.090
# 12   -0.2732     0.078    0.879     0.042
# 13    0.5070     0.000    0.910     0.090
# 14    0.5070     0.000    0.910     0.090
# 15    0.5070     0.000    0.910     0.090
# 16    0.5070     0.000    0.910     0.090
# 17    0.5070     0.000    0.910     0.090
# 18    0.5070     0.000    0.910     0.090
#
#                                               content  \
# 0   J.K. Rowling has been drinking a lot and you'd...
# 1   Yesterday, the prominent bitcoin investor Mich...
# 2   Early next week, Bitcoin is about to experienc...
# 3   Over the last few weeks all eyes in the crypto...
# 4   If youre planning to do some protesting and yo...
# 5   Since the first Bitcoin block was generated ba...
# 6   <ul><li>The cryptocurrency market added $13 bi...
# 7   Reuters\r\n<ul><li>Goldman Sachs gave five rea...
# 8   <ul><li>Famed investor Michael Novogratz tweet...
# 9   Our robot colleague Satoshi Nakaboto writes ab...
# 10  The move is the latest in a string of positive...
# 11  Our robot colleague Satoshi Nakaboto writes ab...
# 12  Opinions expressed by Entrepreneur contributor...
# 13  Our robot colleague Satoshi Nakaboto writes ab...
# 14  Our robot colleague Satoshi Nakaboto writes ab...
# 15  Our robot colleague Satoshi Nakaboto writes ab...
# 16  Our robot colleague Satoshi Nakaboto writes ab...
# 17  Our robot colleague Satoshi Nakaboto writes ab...
# 18  Our robot colleague Satoshi Nakaboto writes ab...
#
#                                                tokens
# 0   [jk, rowling, drinking, lot, youd, better, bel...
# 1   [yesterday, prominent, bitcoin, investor, mich...
# 2   [early, next, week, bitcoin, experience, third...
# 3   [last, week, eye, crypto, world, glued, halven...
# 4   [youre, planning, protesting, dont, want, risk...
# 5   [since, first, bitcoin, block, generated, back...
# 6   [ullithe, cryptocurrency, market, added, 13, b...
# 7   [reutersulligoldman, sachs, gave, five, reason...
# 8   [ullifamed, investor, michael, novogratz, twee...
# 9   [robot, colleague, satoshi, nakaboto, writes, ...
# 10  [move, latest, string, positive, development, ...
# 11  [robot, colleague, satoshi, nakaboto, writes, ...
# 12  [opinion, expressed, entrepreneur, contributor...
# 13  [robot, colleague, satoshi, nakaboto, writes, ...
# 14  [robot, colleague, satoshi, nakaboto, writes, ...
# 15  [robot, colleague, satoshi, nakaboto, writes, ...
# 16  [robot, colleague, satoshi, nakaboto, writes, ...
# 17  [robot, colleague, satoshi, nakaboto, writes, ...
# 18  [robot, colleague, satoshi, nakaboto, writes, ...

# %%
# Create a new tokens column for ethereum
eth_sentiment_df['tokens'] = eth_sentiment_df['content'].apply(tokenizer)
eth_sentiment_df
# Out:
#     Compound  Negative  Neutral  Positive  \
# 0     0.0000     0.000    1.000     0.000
# 1     0.0000     0.000    1.000     0.000
# 2     0.6249     0.000    0.859     0.141
# 3    -0.4457     0.086    0.882     0.031
# 4     0.0000     0.148    0.703     0.148
# 5     0.0000     0.000    1.000     0.000
# 6     0.5719     0.000    0.885     0.115
# 7     0.2732     0.000    0.943     0.057
# 8     0.0772     0.058    0.877     0.066
# 9     0.5070     0.000    0.910     0.090
# 10    0.9198     0.000    0.665     0.335
# 11    0.3182     0.000    0.933     0.067
# 12   -0.2732     0.078    0.879     0.042
# 13    0.0000     0.000    1.000     0.000
# 14    0.7634     0.033    0.729     0.238
# 15    0.0000     0.000    1.000     0.000
#
#                                               content  \
# 0   Editors note:Andreessen Horowitzs Crypto Start...
# 1   For developers looking to quickly build identi...
# 2   Use this to send Ether from one account to ano...
# 3   Some open-source groups, such as The Linux Fou...
# 4   With unemployment surging and businesses strug...
# 5   Over the last few weeks all eyes in the crypto...
# 6   We have been looking for ways in which crypto ...
# 7   Back in March, we put out our call for ideas t...
# 8   <ul><li>The cryptocurrency market added $13 bi...
# 9   Our robot colleague Satoshi Nakaboto writes ab...
# 10  Blockchain technology is cementing its positio...
# 11  Opinions expressed by Entrepreneur contributor...
# 12  Opinions expressed by Entrepreneur contributor...
# 13  After Facebook and Telegram, Reddit is the nex...
# 14  Why?\r\nBecause I get to program innovative an...
# 15  Federal Reserve Board Chairman Jerome H. Powel...
#
#                                                tokens
# 0   [editor, noteandreessen, horowitz, crypto, sta...
# 1   [developer, looking, quickly, build, identity,...
# 2   [use, send, ether, one, account, another, smar...
# 3   [opensource, group, linux, foundation, deal, o...
# 4   [unemployment, surging, business, struggling, ...
# 5   [last, week, eye, crypto, world, glued, halven...
# 6   [looking, way, crypto, asset, go, mainstream, ...
# 7   [back, march, put, call, idea, fixtheinternet,...
# 8   [ullithe, cryptocurrency, market, added, 13, b...
# 9   [robot, colleague, satoshi, nakaboto, writes, ...
# 10  [blockchain, technology, cementing, position, ...
# 11  [opinion, expressed, entrepreneur, contributor...
# 12  [opinion, expressed, entrepreneur, contributor...
# 13  [facebook, telegram, reddit, next, major, soci...
# 14  [whybecause, get, program, innovative, creativ...
# 15  [federal, reserve, board, chairman, jerome, h,...

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
def get_token(df):
    tokens = []
    for i in df['tokens']:
        tokens.extend(i)
    return tokens

btc_tokens = get_token(btc_sentiment_df)
eth_tokens = get_token(eth_sentiment_df)

# %%
# Generate the Bitcoin N-grams where N=2
def bigram_counter(tokens, N):
    words_count = dict(Counter(ngrams(tokens, n=N)))
    return words_count

# %%
bigram_btc = bigram_counter(btc_tokens, 2)
bigram_btc
# Out:
# {('jk', 'rowling'): 1,
#  ('rowling', 'four'): 1,
#  ('four', 'cocktail'): 1,
#  ('cocktail', 'talking'): 1,
#  ('talking', 'trash'): 1,
#  ('trash', 'bitcoin'): 1,
#  ('bitcoin', 'teenager'): 1,
#  ('teenager', 'accused'): 1,
#  ('accused', 'leading'): 1,
#  ('leading', 'ring'): 1,
#  ('ring', 'evil'): 1,
#  ('evil', 'genius'): 1,
#  ('genius', '24'): 1,
#  ('24', 'million'): 1,
#  ('million', 'cybercrime'): 1,
#  ('cybercrime', 'spree'): 1,
#  ('spree', 'massive'): 1,
#  ('massive', 'bitcoin'): 1,
#  ('bitcoin', 'event'): 1,
#  ('event', 'coming'): 1,
#  ('coming', 'next'): 1,
#  ('next', 'week'): 1,
#  ('week', 'here'): 1,
#  ('here', 'need'): 1,
#  ('need', 'know'): 1,
#  ('know', 'falconx'): 1,
#  ('falconx', 'raise'): 1,
#  ('raise', '17m'): 1,
#  ('17m', 'power'): 1,
#  ('power', 'crypto'): 1,
#  ('crypto', 'trading'): 1,
#  ('trading', 'service'): 1,
#  ('service', 'buy'): 1,
#  ('buy', 'burner'): 1,
#  ('burner', 'phone'): 1,
#  ('phone', 'happened'): 1,
#  ('happened', 'bitcoin'): 1,
#  ('bitcoin', 'experienced'): 1,
#  ('experienced', 'third'): 1,
#  ('third', 'halving'): 1,
#  ('halving', 'history'): 1,
#  ('history', 'crypto'): 1,
#  ('crypto', 'market'): 1,
#  ('market', 'grows'): 1,
#  ('grows', '13'): 1,
#  ('13', 'billion'): 1,
#  ('billion', 'bitcoin'): 1,
#  ('bitcoin', 'break'): 1,
#  ('break', '10000'): 2,
#  ('10000', 'threshold'): 2,
#  ('threshold', 'first'): 1,
#  ('first', 'time'): 1,
#  ('time', 'since'): 1,
#  ('since', 'february'): 1,
#  ('february', 'btc'): 1,
#  ('btc', 'halving'): 1,
#  ('halving', 'boost'): 1,
#  ('boost', 'bitcoin'): 1,
#  ('bitcoin', 'price'): 1,
#  ('price', 'cnbc'): 1,
#  ('cnbc', 'television'): 1,
#  ('television', 'goldman'): 1,
#  ('goldman', 'sachs'): 2,
#  ('sachs', 'list'): 1,
#  ('list', '5'): 1,
#  ('5', 'reason'): 1,
#  ('reason', 'bitcoin'): 1,
#  ('bitcoin', 'asset'): 1,
#  ('asset', 'class'): 1,
#  ('class', 'suitable'): 1,
#  ('suitable', 'investment'): 1,
#  ('investment', 'btcusd'): 1,
#  ('btcusd', 'get'): 1,
#  ('get', 'train'): 1,
#  ('train', 'famed'): 1,
#  ('famed', 'investor'): 1,
#  ('investor', 'michael'): 1,
#  ('michael', 'novogratz'): 1,
#  ('novogratz', 'say'): 1,
#  ('say', 'bitcoin'): 1,
#  ('bitcoin', 'soon'): 1,
#  ('soon', 'break'): 1,
#  ('threshold', 'u'): 1,
#  ('u', 'turmoil'): 1,
#  ('turmoil', 'spread'): 1,
#  ('spread', 'btcusd'): 1,
#  ('btcusd', 'satoshi'): 1,
#  ('satoshi', 'nakaboto'): 8,
#  ('nakaboto', 'bitcoin'): 5,
#  ('bitcoin', 'continues'): 1,
#  ('continues', 'downtrend'): 1,
#  ('downtrend', '5'): 1,
#  ('5', 'loss'): 1,
#  ('loss', 'one'): 1,
#  ('one', 'day'): 1,
#  ('day', 'jpmorgan'): 1,
#  ('jpmorgan', 'extends'): 1,
#  ('extends', 'banking'): 1,
#  ('banking', 'service'): 2,
#  ('service', 'bitcoin'): 2,
#  ('bitcoin', 'exchange'): 2,
#  ('exchange', 'satoshi'): 1,
#  ('nakaboto', 'visa'): 1,
#  ('visa', 'approves'): 1,
#  ('approves', 'launch'): 1,
#  ('launch', 'crypto'): 1,
#  ('crypto', 'debit'): 1,
#  ('debit', 'card'): 1,
#  ('card', 'europe'): 1,
#  ('europe', '8'): 1,
#  ('8', 'reason'): 1,
#  ('reason', 'could'): 1,
#  ('could', 'time'): 1,
#  ('time', 'take'): 1,
#  ('take', 'bitcoin'): 1,
#  ('bitcoin', 'seriously'): 1,
#  ('seriously', 'satoshi'): 1,
#  ('bitcoin', 'close'): 1,
#  ('close', '10000'): 1,
#  ('10000', 'satoshi'): 1,
#  ('bitcoin', 'bad'): 1,
#  ('bad', 'investment'): 1,
#  ('investment', 'according'): 1,
#  ('according', 'goldman'): 1,
#  ('sachs', 'satoshi'): 1,
#  ('nakaboto', 'sp'): 1,
#  ('sp', '500'): 1,
#  ('500', 'outperformed'): 1,
#  ('outperformed', 'bitcoin'): 1,
#  ('bitcoin', 'past'): 1,
#  ('past', 'year'): 1,
#  ('year', 'satoshi'): 1,
#  ('bitcoin', 'whale'): 1,
#  ('whale', 'move'): 1,
#  ('move', '400m'): 1,
#  ('400m', 'pay'): 1,
#  ('pay', '250'): 1,
#  ('250', 'fee'): 1,
#  ('fee', 'satoshi'): 1,
#  ('bitcoin', 'plummet'): 1,
#  ('plummet', 'almost'): 1,
#  ('almost', '700'): 1,
#  ('700', 'hour'): 1,
#  ('hour', 'back'): 1,
#  ('back', '10k'): 1,
#  ('10k', 'satoshi'): 1,
#  ('nakaboto', 'jpmorgan'): 1,
#  ('jpmorgan', 'offer'): 1,
#  ('offer', 'banking'): 1}

# %%
# Generate the Ethereum N-grams where N=2
bigram_eth = bigram_counter(eth_tokens, 2)
bigram_eth
# Out:
# {('crypto', 'startup'): 1,
#  ('startup', 'school'): 1,
#  ('school', 'scale'): 1,
#  ('scale', 'company'): 1,
#  ('company', 'using'): 1,
#  ('using', 'crypto'): 1,
#  ('crypto', 'decentralized'): 1,
#  ('decentralized', 'identity'): 1,
#  ('identity', 'management'): 1,
#  ('management', 'platform'): 1,
#  ('platform', 'magic'): 1,
#  ('magic', 'launch'): 1,
#  ('launch', 'stealth'): 1,
#  ('stealth', '4m'): 1,
#  ('4m', 'web3'): 1,
#  ('web3', 'javascript'): 1,
#  ('javascript', 'function'): 1,
#  ('function', 'ethereum'): 1,
#  ('ethereum', 'dapps'): 1,
#  ('dapps', 'fo'): 1,
#  ('fo', 'responder'): 1,
#  ('responder', 'want'): 1,
#  ('want', 'help'): 1,
#  ('help', 'opensource'): 1,
#  ('opensource', 'group'): 1,
#  ('group', 'survive'): 1,
#  ('survive', 'u'): 1,
#  ('u', 'could'): 1,
#  ('could', 'deliver'): 1,
#  ('deliver', 'stimulus'): 1,
#  ('stimulus', 'check'): 1,
#  ('check', 'fasterwith'): 1,
#  ('fasterwith', 'tech'): 1,
#  ('tech', 'help'): 1,
#  ('help', 'falconx'): 1,
#  ('falconx', 'raise'): 1,
#  ('raise', '17m'): 1,
#  ('17m', 'power'): 1,
#  ('power', 'crypto'): 1,
#  ('crypto', 'trading'): 1,
#  ('trading', 'service'): 1,
#  ('service', 'rcryptocurrency'): 1,
#  ('rcryptocurrency', 'moon'): 1,
#  ('moon', 'td'): 1,
#  ('td', 'ameritradebacked'): 1,
#  ('ameritradebacked', 'erisx'): 1,
#  ('erisx', 'launch'): 1,
#  ('launch', 'first'): 1,
#  ('first', 'ethereum'): 1,
#  ('ethereum', 'future'): 1,
#  ('future', 'trading'): 1,
#  ('trading', 'platform'): 1,
#  ('platform', 'u'): 1,
#  ('u', 'authorized'): 1,
#  ('authorized', 'regulator'): 1,
#  ('regulator', 'alexander'): 1,
#  ('alexander', 'behrensdecrypt'): 1,
#  ('behrensdecrypt', 'mozillas'): 1,
#  ('mozillas', 'fixtheinternet'): 1,
#  ('fixtheinternet', 'incubator'): 1,
#  ('incubator', 'reddit'): 1,
#  ('reddit', 'beta'): 1,
#  ('beta', 'testing'): 1,
#  ('testing', 'two'): 1,
#  ('two', 'ethereumbased'): 1,
#  ('ethereumbased', 'token'): 1,
#  ('token', 'user'): 1,
#  ('user', 'earn'): 1,
#  ('earn', 'reward'): 1,
#  ('reward', 'contributing'): 1,
#  ('contributing', 'content'): 1,
#  ('content', 'subreddits'): 1,
#  ('subreddits', 'rcryptocurrency'): 1,
#  ('rcryptocurrency', 'rfortnitebr'): 1,
#  ('rfortnitebr', 'celia'): 1,
#  ('celia', 'wanthe'): 1,
#  ('wanthe', 'block'): 1,
#  ('block', 'consensys'): 1,
#  ('consensys', 'helped'): 1,
#  ('helped', 'north'): 1,
#  ('north', 'american'): 1,
#  ('american', 'collegiate'): 1,
#  ('collegiate', 'league'): 1,
#  ('league', 'build'): 1,
#  ('build', 'ethereumbased'): 1,
#  ('ethereumbased', 'service'): 1,
#  ('service', 'make'): 1,
#  ('make', 'reporting'): 1,
#  ('reporting', 'smoother'): 1,
#  ('smoother', 'automate'): 1,
#  ('automate', 'payment'): 1,
#  ('payment', 'esports'): 1,
#  ('esports', 'tournament'): 1,
#  ('tournament', 'jeff'): 1,
#  ('jeff', 'bensondecrypt'): 1,
#  ('bensondecrypt', 'crypto'): 1,
#  ('crypto', 'market'): 1,
#  ('market', 'grows'): 1,
#  ('grows', '13'): 1,
#  ('13', 'billion'): 1,
#  ('billion', 'bitcoin'): 1,
#  ('bitcoin', 'break'): 1,
#  ('break', '10000'): 1,
#  ('10000', 'threshold'): 1,
#  ('threshold', 'first'): 1,
#  ('first', 'time'): 1,
#  ('time', 'since'): 1,
#  ('since', 'february'): 1,
#  ('february', 'btc'): 1,
#  ('btc', 'satoshi'): 1,
#  ('satoshi', 'nakaboto'): 1,
#  ('nakaboto', 'bitcoin'): 1,
#  ('bitcoin', 'way'): 1,
#  ('way', 'back'): 1,
#  ('back', '10000'): 1,
#  ('10000', '10'): 1,
#  ('10', 'way'): 1,
#  ('way', 'skyrocket'): 1,
#  ('skyrocket', 'business'): 1,
#  ('business', 'growth'): 1,
#  ('growth', 'using'): 1,
#  ('using', 'blockchain'): 1,
#  ('blockchain', 'technology'): 1,
#  ('technology', 'around'): 1,
#  ('around', '8m'): 1,
#  ('8m', 'bitcoin'): 1,
#  ('bitcoin', 'lightning'): 1,
#  ('lightning', 'network'): 1,
#  ('network', 'two'): 1,
#  ('two', 'year'): 1,
#  ('year', 'launching'): 1,
#  ('launching', 'beta'): 1,
#  ('beta', 'le'): 1,
#  ('le', '115m'): 1,
#  ('115m', 'locked'): 1,
#  ('locked', 'ethereum'): 1,
#  ('ethereum', 'wallet'): 1,
#  ('wallet', 'dapps'): 1,
#  ('dapps', 'liam'): 1,
#  ('liam', 'frostdecrypt'): 1,
#  ('frostdecrypt', '4'): 1,
#  ('4', 'fun'): 1,
#  ('fun', 'way'): 1,
#  ('way', 'millennials'): 1,
#  ('millennials', 'dip'): 1,
#  ('dip', 'toe'): 1,
#  ('toe', 'investing'): 1,
#  ('investing', '8'): 1,
#  ('8', 'reason'): 1,
#  ('reason', 'could'): 1,
#  ('could', 'time'): 1,
#  ('time', 'take'): 1,
#  ('take', 'bitcoin'): 1,
#  ('bitcoin', 'seriously'): 1,
#  ('seriously', 'reddit'): 1,
#  ('reddit', 'test'): 1,
#  ('test', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'reward'): 1,
#  ('reward', 'user'): 1,
#  ('user', 'boosting'): 1,
#  ('boosting', 'engagement'): 1,
#  ('engagement', 'left'): 1,
#  ('left', 'trivago'): 1,
#  ('trivago', 'become'): 1,
#  ('become', 'blockchain'): 1,
#  ('blockchain', 'developer'): 1,
#  ('developer', 'federal'): 1,
#  ('federal', 'endorses'): 1,
#  ('endorses', 'ethereumbacked'): 1,
#  ('ethereumbacked', 'alternative'): 1,
#  ('alternative', 'libor'): 1}

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin
token_count(btc_tokens, 10)
# Out:
# [('bitcoin', 16),
#  ('satoshi', 8),
#  ('nakaboto', 8),
#  ('crypto', 3),
#  ('service', 3),
#  ('10000', 3),
#  ('halving', 2),
#  ('break', 2),
#  ('threshold', 2),
#  ('time', 2)]

# %%
# Get the top 10 words for Ethereum
token_count(eth_tokens, 10)
# Out:
# [('crypto', 4),
#  ('bitcoin', 4),
#  ('ethereum', 3),
#  ('way', 3),
#  ('using', 2),
#  ('platform', 2),
#  ('launch', 2),
#  ('dapps', 2),
#  ('help', 2),
#  ('u', 2)]

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
wc = WordCloud().generate(' '.join(btc_tokens))
plt.title("Bitcoin Word Cloud", fontsize = 50, fontweight = 'bold')
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
wc = WordCloud().generate(' '.join(eth_tokens))
plt.title("Ethereum Word Cloud", fontsize = 50, fontweight = 'bold')
plt.imshow(wc)

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Optional - download a language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
btc_content = ' '.join(btc_sentiment_df['content'])
btc_content
# Out:
# 'J.K. Rowling has been drinking a lot and you\'d better believe she has some thoughts on Bitcoin.\r\nNotedTERF and author of The Cuckoos Calling, Rowlingdecided Friday was the perfect time to learn about… [+2124 chars] Yesterday, the prominent bitcoin investor Michael Terpin announced that hed filed suit against the ringleader of a SIM swap gang that hed been chasing down since 2018, following the theft of roughly … [+2243 chars] Early next week, Bitcoin is about to experience its third-ever halving, a hugely important event that could shift the balance of power within the network. Historically the event, also called the halv… [+7424 chars] Over the last few weeks all eyes in the crypto world have been glued to the halvening, a nigh-religious moment in the blockchain realm. Every once in a while, the amount of new bitcoin mined — distri… [+4849 chars] If youre planning to do some protesting and you dont want to risk your expensive smartphone in the processor you simply want to keep yourself as anonymous as possible while youre outconsider buying a… [+5568 chars] Since the first Bitcoin block was generated back in 2009, there have been three halving events. Taking place once every 210,000 blocks mined, or approximately once every four years, a Bitcoin halving… [+1044 chars] <ul><li>The cryptocurrency market added $13 billion in value over the past day as bitcoin jumped more than 6% Thursday evening.</li><li>Bitcoin has rallied more than 100% from its March 16 low and ha… [+3575 chars] Reuters\r\n<ul><li>Goldman Sachs gave five reasons why it thinks bitcoin is "not an asset class" nor "a suitable investment" in a presentation Wednesday morning.</li><li>Goldman observed that the crypt… [+3412 chars] <ul><li>Famed investor Michael Novogratz tweeted on Monday that bitcoin will soon take out the $10,000 resistance level, telling his followers, "Get on the train."</li><li>Novogratz said that turmoil… [+2757 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3004 chars] The move is the latest in a string of positive developments for bitcoin and another sign that Wall Street is becoming more comfortable with the business of cryptocurrencies. Coinbase, founded in 2012… [+1067 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the … [+3041 chars] Opinions expressed by Entrepreneur contributors are their own.\r\nDespite recent price volatility\xa0and global macroeconomic uncertainty, 2020 is a big year for Bitcoin. Although a large number of busine… [+6168 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3080 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3009 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2941 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2953 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3328 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another ed ...

# %%
# Run the NER processor on all of the text
doc = nlp(btc_content)

# Add a title to the document
doc.user_data["title"] = "BITCOIN NER"

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <h2 style="margin: 0">BITCOIN NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     J.K. Rowling
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has been drinking a lot and you'd better believe she has some thoughts on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>NotedTERF and author of
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Cuckoos Calling
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# , Rowlingdecided
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  was the perfect time to learn about… [+2124 chars]
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yesterday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the prominent bitcoin investor
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michael Terpin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  announced that hed filed suit against the ringleader of a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SIM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  swap gang that hed been chasing down since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , following the theft of roughly … [+2243 chars]
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Early next week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is about to experience its
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# -ever halving, a hugely important event that could shift the balance of power within the network. Historically the event, also called the halv… [+7424 chars] Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last few weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  all eyes in the crypto world have been glued to the halvening, a nigh-religious moment in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     blockchain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  realm. Every once in a while, the amount of
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  mined — distri… [+4849 chars] If youre planning to do some protesting and you dont want to risk your expensive smartphone in the processor you simply want to keep yourself as anonymous as possible while youre outconsider buying a… [+5568 chars] Since the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  block was generated back in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2009
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , there have been
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  halving events. Taking place once every
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     210,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  blocks mined, or approximately once
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     every four years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em

# %%
# List all Entities
for ent in doc.ents:
    print('{} {}'.format(ent.text, ent.label_))
# Out:
# J.K. Rowling PERSON
# Bitcoin GPE
# The Cuckoos Calling WORK_OF_ART
# Friday DATE
# Yesterday DATE
# Michael Terpin PERSON
# SIM ORG
# 2018 DATE
# Early next week DATE
# Bitcoin GPE
# third ORDINAL
# the last few weeks DATE
# blockchain GPE
# new bitcoin LOC
# first ORDINAL
# Bitcoin GPE
# 2009 DATE
# three CARDINAL
# 210,000 CARDINAL
# every four years DATE
# Bitcoin GPE
# $13 billion MONEY
# the past day DATE
# bitcoin GPE
# more than 6% PERCENT
# Thursday DATE
# Bitcoin GPE
# more than 100% PERCENT
# March 16 DATE
# Reuters
#  ORG
# Goldman Sachs ORG
# five CARDINAL
# bitcoin GPE
# Wednesday DATE
# Goldman ORG
# Michael Novogratz PERSON
# Monday DATE
# bitcoin GPE
# $10,000 resistance MONEY
# Novogratz PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# bitcoin GPE
# 2012 DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# 2020 DATE
# a big year DATE
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the bitcoin text together
eth_content = ' '.join(eth_sentiment_df['content'])
eth_content
# Out:
# 'Editors note:Andreessen Horowitzs Crypto Startup School brought together 45 participants from around the U.S. and overseas in a seven-week course to learn how to build crypto companies. Andreessen Ho… [+2503 chars] For developers looking to quickly build identity management into their platforms, the most readily available options don’t stray far from the internet’s biggest, most data-hungry platforms.\r\nMagic, a… [+2450 chars] Use this to send Ether from one account to another or a smart contract address. It requires a few parameters depending on the transaction. Possible parameters include from, to, value, gas, and more.\r… [+206 chars] Some open-source groups, such as The Linux Foundation, can deal with it. Others aren\'t so fortunate. Some, such as Drupal Foundation, the Open Source Initiative (OSI), Open Source Matters (Joomla), a… [+1202 chars] With unemployment surging and businesses struggling under lockdown, millions of Americans are relying on the extra benefits payments issued under the $2 trillion dollar Coronavirus Aid, Relief and Ec… [+5094 chars] Over the last few weeks all eyes in the crypto world have been glued to the halvening, a nigh-religious moment in the blockchain realm. Every once in a while, the amount of new bitcoin mined — distri… [+4849 chars] We have been looking for ways in which crypto assets can go mainstream. Our interest and investment in Dapper’s crypto games is an effort in that area. So is our involvement in the Libra project. \r\nW… [+1743 chars] Back in March, we put out our call for ideas to "fix-the-internet". 1500 of you showed up and well over a hundred projects are now underway. Now we\'re launching our v2: the Mozilla Builders Incubator… [+469 chars] <ul><li>The cryptocurrency market added $13 billion in value over the past day as bitcoin jumped more than 6% Thursday evening.</li><li>Bitcoin has rallied more than 100% from its March 16 low and ha… [+3575 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3070 chars] Blockchain technology is cementing its position in the business marketplace to help you get more customers. Gratefully, the first thing that blockchain will help with is better security. But it’s goi… [+9561 chars] Opinions expressed by Entrepreneur contributors are their own.\r\nCalling all millennials:\xa0How much of your money is in equity\xa0or invested somewhere? Sure, there may be a savings account in a mutual fu… [+4116 chars] Opinions expressed by Entrepreneur contributors are their own.\r\nDespite recent price volatility\xa0and global macroeconomic uncertainty, 2020 is a big year for Bitcoin. Although a large number of busine… [+6168 chars] After Facebook and Telegram, Reddit is the next major social media platform to venture into the world of cryptocurrencies. The self-proclaimed “front page of the internet” is testing a cryptocurrency… [+1413 chars] Why?\r\nBecause I get to program innovative and creative solutions for many unresolved challenges our society faces today.\r\nBecause I am relatively young (27) and I don\'t want to compete for Java posit… [+8262 chars] Federal Reserve Board Chairman Jerome H. Powell provided a statement on May 28, 2020, regarding the suitability of AMERIBOR as a replacement to LIBOR. AMERIBOR uses a permissioned version of Ethereum… [+6230 chars]'

# %%
# Run the NER processor on all of the text
doc = nlp(eth_content)

# Add a title to the document
doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Editors note:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Andreessen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Horowitzs
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crypto Startup School
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  brought together
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     45
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  participants from around the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and overseas in a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seven-week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  course to learn how to build crypto companies.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Andreessen Ho
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Magic, a… [+2450 chars] Use this to send
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ether
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# … [+206 chars] Some open-source groups, such as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Linux Foundation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , can deal with it. Others aren't so fortunate. Some, such as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Drupal Foundation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the Open Source Initiative (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OSI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ), Open Source Matters (Joomla), a… [+1202 chars] With unemployment surging and businesses struggling under lockdown,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     millions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  are relying on the extra benefits payments issued under the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $2 trillion dollar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  Coronavirus Aid,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Relief
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ec
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# … [+5094 chars] Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last few weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  all eyes in the crypto world have been glued to the halvening, a nigh-religious moment in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     blockchain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  realm. Every once in a while, the amount of
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  mined — distri… [+4849 chars] We have been looking for ways in which
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     crypto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  assets can go mainstream. Our interest and investment in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dapper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s crypto games is an effort in that area. So is our involvement in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Libra
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>W… [+1743 chars] Back in
# <mark

# %%
# List all Entities
for ent in doc.ents:
    print('{} {}'.format(ent.text, ent.label_))
# Out:
# Andreessen ORG
# Crypto Startup School ORG
# 45 CARDINAL
# U.S. GPE
# seven-week DATE
# Andreessen Ho PERSON
# Ether PERSON
# The Linux Foundation ORG
# Drupal Foundation ORG
# OSI ORG
# millions CARDINAL
# Americans NORP
# $2 trillion dollar MONEY
# Relief ORG
# Ec ORG
# the last few weeks DATE
# blockchain GPE
# new bitcoin LOC
# crypto NORP
# Dapper ORG
# Libra GPE
# March DATE
# 1500 CARDINAL
# well over a hundred CARDINAL
# the Mozilla Builders Incubator ORG
# $13 billion MONEY
# the past day DATE
# bitcoin GPE
# more than 6% PERCENT
# Thursday DATE
# Bitcoin GPE
# more than 100% PERCENT
# March 16 DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Blockchain GPE
# first ORDINAL
# blockchain GPE
# 2020 DATE
# a big year DATE
# Bitcoin GPE
# today DATE
# 27 CARDINAL
# Java PERSON
# Federal Reserve Board ORG
# Jerome H. Powell PERSON
# May 28, 2020 DATE
