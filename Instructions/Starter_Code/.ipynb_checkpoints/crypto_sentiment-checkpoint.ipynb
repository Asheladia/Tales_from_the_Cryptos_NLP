# %%
import os
import pandas as pd
from newsapi import NewsApiClient
# %matplotlib inline

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Read your api key environment variable
api_key = 'c7825a5cbc5240d2a9245f8ec5ccc703'

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
btc_articles = newsapi.get_everything(q='bitcoin',
                                      language='en',
                                      sort_by='relevancy',
                                      )
btc_articles
# Out:
# {'status': 'ok',
#  'totalResults': 3579,
#  'articles': [{'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Jack Morse',
#    'title': 'J.K. Rowling is four cocktails in and talking trash about Bitcoin',
#    'description': "J.K. Rowling has been drinking a lot and you'd better believe she has some thoughts on Bitcoin.\nNoted TERF and author of The Cuckoo’s Calling, Rowling decided Friday was the perfect time to learn about the cryptocurrency Bitcoin. And so, like any celebrity wh…",
#    'url': 'https://mashable.com/article/jk-rowling-asked-twitter-about-bitcoin/',
#    'urlToImage': 'https://mondrian.mashable.com/2020%252F05%252F16%252Fed%252F65127486efd14faea068927124f3b1ee.253ab.jpg%252F1200x630.jpg?signature=XjJ4aqKaX56MW5k29Zn1ygz0Evc=',
#    'publishedAt': '2020-05-16T00:34:00Z',
#    'content': "J.K. Rowling has been drinking a lot and you'd better believe she has some thoughts on Bitcoin.\r\nNotedTERF and author of The Cuckoos Calling, Rowlingdecided Friday was the perfect time to learn about… [+2124 chars]"},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Tom McKay',
#    'title': 'God Help Us, the Winklevoss Twins Are Co-Producing a Movie About Their Bitcoin Journey',
#    'description': 'The Winklevoss twins—the brothers Mark Zuckerberg allegedly stole the idea for Facebook from—are making a movie about themselves, Deadline reported this week. If that doesn’t seem masturbatory enough, rejoice: said film is about how they amassed a net wealth …',
#    'url': 'https://gizmodo.com/god-help-us-the-winklevoss-twins-are-co-producing-a-mo-1843973511',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/iujekjzgrttsevxxzbop.jpg',
#    'publishedAt': '2020-06-09T23:45:00Z',
#    'content': 'The Winklevoss twinsthe brothers Mark Zuckerberg allegedly stole the idea for Facebook fromare making a movie about themselves, Deadline reported this week. If that doesnt seem masturbatory enough, r… [+2657 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Alex Wilhelm',
#    'title': 'FalconX raises $17M to power its crypto trading service',
#    'description': 'Over the last few weeks all eyes in the crypto world have been glued to the halvening, a nigh-religious moment in the blockchain realm. Every once in a while, the amount of new bitcoin mined — distributed to miners, the folks with fleets of computers powering…',
#    'url': 'http://techcrunch.com/2020/05/13/falconx-raises-17m-to-power-its-crypto-trading-service/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/04/bitcoin-bitfinex.jpg?w=750',
#    'publishedAt': '2020-05-13T15:46:38Z',
#    'content': 'Over the last few weeks all eyes in the crypto world have been glued to the halvening, a nigh-religious moment in the blockchain realm. Every once in a while, the amount of new bitcoin mined — distri… [+4849 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'David Murphy',
#    'title': 'How to Buy a Burner Phone',
#    'description': 'If you’re planning to do some protesting and you don’t want to risk your expensive smartphone in the process—or you simply want to keep yourself as anonymous as possible while you’re out—consider buying a burner phone. Yes, it’ll cost a little cash, but picki…',
#    'url': 'https://lifehacker.com/how-to-buy-a-burner-phone-1843905326',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/qtukpcqooat11zbahjwg.jpg',
#    'publishedAt': '2020-06-04T19:00:00Z',
#    'content': 'If youre planning to do some protesting and you dont want to risk your expensive smartphone in the processor you simply want to keep yourself as anonymous as possible while youre outconsider buying a… [+5568 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Matthew Fox',
#    'title': "Goldman Sachs lists 5 reasons why bitcoin is 'not an asset class', nor 'a suitable investment' (BTCUSD)",
#    'description': '<ul>\n<li>Goldman Sachs gave five reasons why it thinks bitcoin is "not an asset class" nor "a suitable investment" in a presentation Wednesday morning.</li>\n<li>Goldman observed that the cryptocurrency infrastructure is still young and susceptible to hacking …',
#    'url': 'https://markets.businessinsider.com/currencies/news/bitcoin-goldman-lists-reasons-why-not-asset-class-suitable-investment-2020-5-1029248469',
#    'urlToImage': 'https://images.markets.businessinsider.com/image/5ecfadc8aee6a861af18ac14-2400/2020-05-11t214412z1lynxmpeg4a25artroptp4crypto-currencies-bitcoin-halving.jpg',
#    'publishedAt': '2020-05-28T14:18:38Z',
#    'content': 'Reuters\r\n<ul><li>Goldman Sachs gave five reasons why it thinks bitcoin is "not an asset class" nor "a suitable investment" in a presentation Wednesday morning.</li><li>Goldman observed that the crypt… [+3412 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Matthew Fox',
#    'title': "'Get on the train': Famed investor Michael Novogratz says bitcoin will soon break the $10,000 threshold as US turmoil spreads (BTCUSD)",
#    'description': '<ul>\n<li>Famed investor Michael Novogratz tweeted on Monday that bitcoin will soon take out the $10,000 resistance level, telling his followers, "Get on the train."</li>\n<li>Novogratz said that turmoil spreading throughout the US only adds to the bitcoin narr…',
#    'url': 'https://www.businessinsider.com/bitcoin-price-novogratz-forecast-says-break-level-us-turmoil-spreads-2020-6',
#    'urlToImage': 'https://i.insider.com/5ed65008f0f4195f641c1656?width=1200&format=jpeg',
#    'publishedAt': '2020-06-02T14:19:53Z',
#    'content': '<ul><li>Famed investor Michael Novogratz tweeted on Monday that bitcoin will soon take out the $10,000 resistance level, telling his followers, "Get on the train."</li><li>Novogratz said that turmoil… [+2757 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin continues downtrend with 5% loss in one day’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Satoshi Nakamoto used to say: Time to lear…',
#    'url': 'https://thenextweb.com/hardfork/2020/05/25/satoshi-nakaboto-bitcoin-continues-downtrend-with-5-loss-in-one-day/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-05-25T09:46:32Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3004 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'BeauHD',
#    'title': 'JPMorgan Extends Banking Services To Bitcoin Exchanges',
#    'description': 'According to The Wall Street Journal, JPMorgan Chase has taken on Coinbase and Gemini Trust as banking customers (Warning: source paywalled; alternative source) -- "the first time the bank has accepted clients from the cryptocurrency industry." From the repor…',
#    'url': 'https://news.slashdot.org/story/20/05/13/2213222/jpmorgan-extends-banking-services-to-bitcoin-exchanges',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2020-05-14T02:02:00Z',
#    'content': 'The move is the latest in a string of positive developments for bitcoin and another sign that Wall Street is becoming more comfortable with the business of cryptocurrencies. Coinbase, founded in 2012… [+1067 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Visa approves launch of crypto debit card in Europe’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Locke used to say: Let’s add the milk of d…',
#    'url': 'https://thenextweb.com/hardfork/2020/05/26/satoshi-nakaboto-visa-approves-launch-of-crypto-debit-card-in-europe/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-05-26T10:03:18Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the … [+3041 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Oliver Isaacs',
#    'title': '8 Reasons Why This Could Be the Time to Take Bitcoin Seriously',
#    'description': 'You had me at inflation-resistant, says this expert.',
#    'url': 'https://www.entrepreneur.com/article/348168',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1589913472-GettyImages-1174079406.jpg',
#    'publishedAt': '2020-05-22T18:00:00Z',
#    'content': 'Opinions expressed by Entrepreneur contributors are their own.\r\nDespite recent price volatility\xa0and global macroeconomic uncertainty, 2020 is a big year for Bitcoin. Although a large number of busine… [+6168 chars]'},
#   {'source': {'id': None, 'name': 'ReadWrite'},
#    'author': 'Reuben Jackson',
#    'title': 'Bitcoin Emerges as New Standard in Post-COVID Economy?',
#    'description': 'The great disruption of the novel coronavirus could do what nothing else has done so far: give Bitcoin the extra push to become accepted as a reserve currency. The macro economic moment we’re in represents a serious opportunity for Bitcoin use cases. Let’s ta…',
#    'url': 'https://readwrite.com/2020/06/08/bitcoin-emerges-as-new-standard-in-post-covid-economy/',
#    'urlToImage': 'https://images.readwrite.com/wp-content/uploads/2020/05/Bitcoin-Emerges-as-New-Standard-in-Post-COVID-Economy.jpg',
#    'publishedAt': '2020-06-08T21:00:51Z',
#    'content': 'Bitcoin has always had the potential to become a world standard for money. Even if the blockchain that powers Bitcoin lacks the bandwidth to handle the required transaction volume, and even if the wo… [+9396 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin is a bad investment according to Goldman Sachs’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Baudriallard used to say: Let’s get this b…',
#    'url': 'https://thenextweb.com/hardfork/2020/05/28/satoshi-nakaboto-bitcoin-is-a-bad-investment-according-to-goldman-sachs/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-05-28T10:14:33Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3009 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘S&P 500 outperformed Bitcoin over the past year’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Aristotle used to say: Let’s get it! Bitco…',
#    'url': 'https://thenextweb.com/hardfork/2020/05/27/satoshi-nakaboto-sp-500-outperformed-bitcoin-over-the-past-year/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-05-27T10:28:15Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2941 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin whale moves $400M, pays $2.50 fee’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Isaac Newton used to say: Intelligence is …',
#    'url': 'https://thenextweb.com/hardfork/2020/05/22/satoshi-nakaboto-bitcoin-whale-moves-400m-pays-2-50-fee/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-05-22T09:36:55Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2953 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Avocado prices indicated sell signal for Bitcoin in early March’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Ada Lovelace used to say: Let’s make it ro…',
#    'url': 'https://thenextweb.com/hardfork/2020/06/09/satoshi-nakaboto-avocado-prices-indicated-sell-signal-for-bitcoin-in-early-march/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-06-09T10:33:38Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3087 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin plummets almost $700 in an hour, back below $10K’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Stephen Hawking used to say: To infinity, …',
#    'url': 'https://thenextweb.com/hardfork/2020/06/03/satoshi-nakaboto-bitcoin-plummets-almost-700-in-an-hour-back-below-10k/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-06-03T08:30:22Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3328 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin rises 5% for second consecutive day’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Satoshi Nakamoto used to say: Yippee! Bitc…',
#    'url': 'https://thenextweb.com/hardfork/2020/05/15/satoshi-nakaboto-bitcoin-rises-5-for-second-consecutive-day/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-05-15T08:49:51Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3034 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Ex-Facebook exec urges people to buy Bitcoin… again’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Planck used to say: If you love yourself, …',
#    'url': 'https://thenextweb.com/hardfork/2020/05/14/satoshi-nakaboto-ex-facebook-exec-urges-people-to-buy-bitcoin-again/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-05-14T09:16:40Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3263 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin on its way back to $10,000’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Descartes used to say: Let’s get this brea…',
#    'url': 'https://thenextweb.com/hardfork/2020/06/05/satoshi-nakaboto-bitcoin-on-its-way-back-to-10000/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-06-05T10:17:20Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3070 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin hits $10,000 again after corona freefall’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Ada Lovelace used to say: Yippee! Bitcoin …',
#    'url': 'https://thenextweb.com/hardfork/2020/06/02/satoshi-nakaboto-bitcoin-hits-10000-again-after-corona-freefall/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-06-02T09:16:34Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2940 chars]'}]}

# %%
# Fetch the Ethereum news articles
eth_articles = newsapi.get_everything(q='ethereum',
                                      language='en',
                                      sort_by='relevancy',
                                      )
eth_articles
# Out:
# {'status': 'ok',
#  'totalResults': 932,
#  'articles': [{'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Daily Ethereum network fees surpass Bitcoin’s’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Schopenhauer used to say: Do what you love…',
#    'url': 'https://thenextweb.com/hardfork/2020/06/08/satoshi-nakaboto-daily-ethereum-network-fees-surpass-bitcoins/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-06-08T08:38:44Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3095 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Henry Pickavet',
#    'title': 'Crypto Startup School: How to scale companies using crypto',
#    'description': 'In week two of a16z’s Crypto Startup School, three company-builders provide real-world advice on using the qualities of crypto to create new business models and networks.',
#    'url': 'http://techcrunch.com/2020/05/20/crypto-startup-school-how-to-scale-companies-using-crypto/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/05/GettyImages-1170889477.jpg?w=711',
#    'publishedAt': '2020-05-20T19:00:17Z',
#    'content': 'Editors note:Andreessen Horowitzs Crypto Startup School brought together 45 participants from around the U.S. and overseas in a seven-week course to learn how to build crypto companies. Andreessen Ho… [+2503 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Lucas Matney',
#    'title': 'Decentralized identity management platform Magic launches from stealth with $4M',
#    'description': 'For developers looking to quickly build identity management into their platforms, the most readily available options don’t stray far from the internet’s biggest, most data-hungry platforms. Magic, a small SF startup building a decentralized blockchain-based i…',
#    'url': 'http://techcrunch.com/2020/06/03/decentralized-identity-management-platform-magic-launches-from-stealth-with-4m/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/06/Magic-Team-Photo-ETHDenver-2020.jpg?w=600',
#    'publishedAt': '2020-06-03T22:55:42Z',
#    'content': 'For developers looking to quickly build identity management into their platforms, the most readily available options don’t stray far from the internet’s biggest, most data-hungry platforms.\r\nMagic, a… [+2450 chars]'},
#   {'source': {'id': None, 'name': 'Medium'},
#    'author': 'Alex Roan',
#    'title': 'Web3 JavaScript Functions for Ethereum DApps',
#    'description': 'Web3 bridges the gap between the traditional internet and the Ethereum blockchain. It enables users to interact with your DApp through a browser. When using JavaScript for your front end, knowing the…',
#    'url': 'https://medium.com/better-programming/the-top-5-web3-javascript-functions-for-ethereum-dapps-7bc108bfd37',
#    'urlToImage': 'https://miro.medium.com/max/1200/0*jldz3o40zYbFa7WV',
#    'publishedAt': '2020-05-14T11:56:46Z',
#    'content': 'Use this to send Ether from one account to another or a smart contract address. It requires a few parameters depending on the transaction. Possible parameters include from, to, value, gas, and more.\r… [+206 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'EditorDavid',
#    'title': "'FOSS Responders' Want to Help Open-Source Groups Survive",
#    'description': '"Thanks to the coronavirus, technology events have been canceled left and right," writes ZDNet. "This, in turn, is damaging the finances of companies and groups that depend on these events."\n\nSome open-source groups, such as The Linux Foundation, can deal wit…',
#    'url': 'https://news.slashdot.org/story/20/05/23/2351224/foss-responders-want-to-help-open-source-groups-survive',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/opensource_64.png',
#    'publishedAt': '2020-05-24T18:34:00Z',
#    'content': "Some open-source groups, such as The Linux Foundation, can deal with it. Others aren't so fortunate. Some, such as Drupal Foundation, the Open Source Initiative (OSI), Open Source Matters (Joomla), a… [+1202 chars]"},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Shailee Adinolfi',
#    'title': "The US Could Deliver Stimulus Checks Faster—With Tech's Help",
#    'description': 'The federal government desperately needs to take cues from global humanitarian agencies that have developed quick and secure payment tools.',
#    'url': 'https://www.wired.com/story/opinion-the-us-could-deliver-stimulus-checks-faster-with-techs-help/',
#    'urlToImage': 'https://media.wired.com/photos/5eb9e08088ead7be95a5c687/191:100/w_1280,c_limit/OpEd-Money-123496124.jpg',
#    'publishedAt': '2020-05-12T13:00:00Z',
#    'content': 'With unemployment surging and businesses struggling under lockdown, millions of Americans are relying on the extra benefits payments issued under the $2 trillion dollar Coronavirus Aid, Relief and Ec… [+5094 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Alex Wilhelm',
#    'title': 'FalconX raises $17M to power its crypto trading service',
#    'description': 'Over the last few weeks all eyes in the crypto world have been glued to the halvening, a nigh-religious moment in the blockchain realm. Every once in a while, the amount of new bitcoin mined — distributed to miners, the folks with fleets of computers powering…',
#    'url': 'http://techcrunch.com/2020/05/13/falconx-raises-17m-to-power-its-crypto-trading-service/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/04/bitcoin-bitfinex.jpg?w=750',
#    'publishedAt': '2020-05-13T15:46:38Z',
#    'content': 'Over the last few weeks all eyes in the crypto world have been glued to the halvening, a nigh-religious moment in the blockchain realm. Every once in a while, the amount of new bitcoin mined — distri… [+4849 chars]'},
#   {'source': {'id': 'vice-news', 'name': 'Vice News'},
#    'author': 'Kevin Truong, Jordan Pearson',
#    'title': 'Someone Mysteriously Paid $2.5M to Send $133 in Cryptocurrency',
#    'description': 'Was it simply a catastrophically expensive mistake, or something more nefarious? The mining pool is holding on to the fee in case the sender speaks up.',
#    'url': 'https://www.vice.com/en_us/article/z3e4v8/someone-mysteriously-paid-25m-to-send-133-in-ethereum-cryptocurrency',
#    'urlToImage': 'https://video-images.vice.com/test-uploads/articles/5ee10c76f934b8009de6a4b6/lede/1591807361583-man-in-white-shirt-using-macbook-pro-52608.jpeg?crop=1xw:0.8408xh;0xw,0.1592xh&resize=1200:*',
#    'publishedAt': '2020-06-10T16:44:10Z',
#    'content': 'Imagine sending $133 to a friend and being charged a $2.5 million fee. That seems to be the case for a cryptocurrency user who paid a $2.5 million transaction fee during a trade on Wednesday morning … [+2684 chars]'},
#   {'source': {'id': None, 'name': 'Avc.com'},
#    'author': 'Fred Wilson',
#    'title': 'r/CryptoCurrency Moons',
#    'description': 'We have been looking for ways in which crypto assets can go mainstream. Our interest and investment in Dapper’s crypto games is an effort in that area. So is our involvement in the Libra project. We also have been involved in legacy mobile and web apps that h…',
#    'url': 'https://avc.com/2020/05/r-cryptocurrency-moons/',
#    'urlToImage': None,
#    'publishedAt': '2020-05-14T18:18:38Z',
#    'content': 'We have been looking for ways in which crypto assets can go mainstream. Our interest and investment in Dapper’s crypto games is an effort in that area. So is our involvement in the Libra project. \r\nW… [+1743 chars]'},
#   {'source': {'id': None, 'name': 'Mozilla.community'},
#    'author': None,
#    'title': 'Mozilla’s Fix-the-Internet Incubator',
#    'description': 'Help Mozilla build a new generation of startups, products, services, and projects that deliver on the full promise of the internet.',
#    'url': 'https://builders.mozilla.community',
#    'urlToImage': 'https://builders.mozilla.community/assets/img/share.jpg',
#    'publishedAt': '2020-05-26T13:23:54Z',
#    'content': 'Back in March, we put out our call for ideas to "fix-the-internet". 1500 of you showed up and well over a hundred projects are now underway. Now we\'re launching our v2: the Mozilla Builders Incubator… [+469 chars]'},
#   {'source': {'id': None, 'name': 'Techmeme.com'},
#    'author': None,
#    'title': 'ConsenSys has helped North American Collegiate League build an Ethereum-based service to make reporting smoother, automate payments for its esports tournaments (Jeff Benson/Decrypt)',
#    'description': 'Jeff Benson / Decrypt:\nConsenSys has helped North American Collegiate League build an Ethereum-based service to make reporting smoother, automate payments for its esports tournaments\xa0 —\xa0 ConsenSys has partnered with the North American Collegiate League to bri…',
#    'url': 'https://www.techmeme.com/200601/p23',
#    'urlToImage': 'https://cdn.decrypt.co/resize/1024/height/512/wp-content/uploads/2020/06/Excited-gamer-gID_2.jpg',
#    'publishedAt': '2020-06-02T00:10:04Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Techmeme.com'},
#    'author': None,
#    'title': 'Reddit is beta testing two Ethereum-based tokens for users to earn rewards for contributing content to subreddits /r/Cryptocurrency and /r/FortniteBR (Celia Wan/The Block)',
#    'description': 'Celia Wan / The Block:\nReddit is beta testing two Ethereum-based tokens for users to earn rewards for contributing content to subreddits /r/Cryptocurrency and /r/FortniteBR\xa0 —\xa0 Reddit, the popular online forum, is beta testing two Ethereum-based tokens for us…',
#    'url': 'https://www.techmeme.com/200514/p2',
#    'urlToImage': 'https://www.tbstat.com/wp/uploads/2020/05/reddit-1063x675.jpg',
#    'publishedAt': '2020-05-14T06:55:02Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Techmeme.com'},
#    'author': None,
#    'title': 'ConsenSys launches an automated service to track the regulatory compliance of the 280K+ tokens issued on Ethereum (Olga Kharif/Bloomberg)',
#    'description': 'Olga Kharif / Bloomberg:\nConsenSys launches an automated service to track the regulatory compliance of the 280K+ tokens issued on Ethereum\xa0 —\xa0 - ConsenSys know-your-customer product will focus on DeFi\xa0 — Automated system will track 280,000 tokens issued on Et…',
#    'url': 'https://www.techmeme.com/200608/p11',
#    'urlToImage': 'https://assets.bwbx.io/images/users/iqjWHBFdfxIU/iQEAmibNNSv4/v0/1200x1727.jpg',
#    'publishedAt': '2020-06-08T19:30:02Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Hackaday'},
#    'author': 'Jonathan Bennett',
#    'title': 'This Week in Security: Crosstalk, TLS Resumption, And Brave Shenanigans',
#    'description': 'Intel announced CrossTalk, a new side-channel attack that can leak data from CPU buffers. It’s the same story we’ve heard before. Bits of internal CPU state can be inferred by other processes. This attack is a bit different, in that it can leak data across CP…',
#    'url': 'https://hackaday.com/2020/06/12/this-week-in-security-crosstalk-tls-resumption-and-brave-shenanigans/',
#    'urlToImage': 'https://hackaday.com/wp-content/uploads/2016/01/darkarts.jpg',
#    'publishedAt': '2020-06-12T18:05:07Z',
#    'content': 'Intel announced CrossTalk, a new side-channel attack that can leak data from CPU buffers. It’s the same story we’ve heard before. Bits of internal CPU state can be inferred by other processes. This a… [+5744 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Avocado prices indicated sell signal for Bitcoin in early March’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Ada Lovelace used to say: Let’s make it ro…',
#    'url': 'https://thenextweb.com/hardfork/2020/06/09/satoshi-nakaboto-avocado-prices-indicated-sell-signal-for-bitcoin-in-early-march/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-06-09T10:33:38Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3087 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin on its way back to $10,000’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Descartes used to say: Let’s get this brea…',
#    'url': 'https://thenextweb.com/hardfork/2020/06/05/satoshi-nakaboto-bitcoin-on-its-way-back-to-10000/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-06-05T10:17:20Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3070 chars]'},
#   {'source': {'id': None, 'name': 'ReadWrite'},
#    'author': 'Reuben Jackson',
#    'title': 'Bitcoin Emerges as New Standard in Post-COVID Economy?',
#    'description': 'The great disruption of the novel coronavirus could do what nothing else has done so far: give Bitcoin the extra push to become accepted as a reserve currency. The macro economic moment we’re in represents a serious opportunity for Bitcoin use cases. Let’s ta…',
#    'url': 'https://readwrite.com/2020/06/08/bitcoin-emerges-as-new-standard-in-post-covid-economy/',
#    'urlToImage': 'https://images.readwrite.com/wp-content/uploads/2020/05/Bitcoin-Emerges-as-New-Standard-in-Post-COVID-Economy.jpg',
#    'publishedAt': '2020-06-08T21:00:51Z',
#    'content': 'Bitcoin has always had the potential to become a world standard for money. Even if the blockchain that powers Bitcoin lacks the bandwidth to handle the required transaction volume, and even if the wo… [+9396 chars]'},
#   {'source': {'id': None, 'name': 'ReadWrite'},
#    'author': 'Waqas Dogar',
#    'title': '10 Ways to Skyrocket Business Growth Using Blockchain Technology',
#    'description': 'Blockchain technology is cementing its position in the business marketplace to help you get more customers. Gratefully, the first thing that blockchain will help with is better security. But it’s going to take some time for the business community to adopt blo…',
#    'url': 'https://readwrite.com/2020/06/03/10-ways-to-skyrocket-business-growth-using-blockchain-technology/',
#    'urlToImage': 'https://images.readwrite.com/wp-content/uploads/2020/04/Business-Growth-Using-Blockchain-Technology.jpg',
#    'publishedAt': '2020-06-03T18:00:47Z',
#    'content': 'Blockchain technology is cementing its position in the business marketplace to help you get more customers. Gratefully, the first thing that blockchain will help with is better security. But it’s goi… [+9561 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Jennifer Spencer',
#    'title': '4 Fun Ways for Millennials to Dip Their Toes Into Investing',
#    'description': 'Convertible loans, DIY platforms and methods for building that nest egg today.',
#    'url': 'https://www.entrepreneur.com/article/350629',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1589489340-GettyImages-1150767833.jpg',
#    'publishedAt': '2020-05-18T13:30:00Z',
#    'content': 'Opinions expressed by Entrepreneur contributors are their own.\r\nCalling all millennials:\xa0How much of your money is in equity\xa0or invested somewhere? Sure, there may be a savings account in a mutual fu… [+4116 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Oliver Isaacs',
#    'title': '8 Reasons Why This Could Be the Time to Take Bitcoin Seriously',
#    'description': 'You had me at inflation-resistant, says this expert.',
#    'url': 'https://www.entrepreneur.com/article/348168',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1589913472-GettyImages-1174079406.jpg',
#    'publishedAt': '2020-05-22T18:00:00Z',
#    'content': 'Opinions expressed by Entrepreneur contributors are their own.\r\nDespite recent price volatility\xa0and global macroeconomic uncertainty, 2020 is a big year for Bitcoin. Although a large number of busine… [+6168 chars]'}]}

# %%
# Create the Bitcoin sentiment scores DataFrame

# %%
def get_sentiment_score(article, based_on):
    sentiments = []
    for article in article["articles"]:
        try:
            text = article[based_on]
            date = article["publishedAt"][:10]
            sentiment = analyzer.polarity_scores(text)
            compound = sentiment["compound"]
            pos = sentiment["pos"]
            neu = sentiment["neu"]
            neg = sentiment["neg"]
            sentiments.append({
                based_on : text,
                "Compound": compound,
                "Negative": neg,
                "Neutral": neu,
                "Positive": pos
            })
        except AttributeError:
            pass
    # Create DataFrame
    df = pd.DataFrame(sentiments)
    return df

# %%
btc_sentiment_df = get_sentiment_score(btc_articles, 'content')
btc_sentiment_df
# Out:
#     Compound  Negative  Neutral  Positive  \
# 0     0.7650     0.000    0.829     0.171
# 1     0.0000     0.000    1.000     0.000
# 2     0.0000     0.000    1.000     0.000
# 3    -0.3464     0.134    0.819     0.046
# 4    -0.2755     0.070    0.930     0.000
# 5     0.0000     0.000    1.000     0.000
# 6     0.5070     0.000    0.910     0.090
# 7     0.8016     0.000    0.812     0.188
# 8     0.5070     0.000    0.910     0.090
# 9    -0.2732     0.078    0.879     0.042
# 10    0.0000     0.000    1.000     0.000
# 11    0.5070     0.000    0.910     0.090
# 12    0.5070     0.000    0.910     0.090
# 13    0.5070     0.000    0.910     0.090
# 14    0.5070     0.000    0.910     0.090
# 15    0.5070     0.000    0.910     0.090
# 16    0.5070     0.000    0.910     0.090
# 17    0.5070     0.000    0.910     0.090
# 18    0.5070     0.000    0.910     0.090
# 19    0.5070     0.000    0.910     0.090
#
#                                               content
# 0   J.K. Rowling has been drinking a lot and you'd...
# 1   The Winklevoss twinsthe brothers Mark Zuckerbe...
# 2   Over the last few weeks all eyes in the crypto...
# 3   If youre planning to do some protesting and yo...
# 4   Reuters\r\n<ul><li>Goldman Sachs gave five rea...
# 5   <ul><li>Famed investor Michael Novogratz tweet...
# 6   Our robot colleague Satoshi Nakaboto writes ab...
# 7   The move is the latest in a string of positive...
# 8   Our robot colleague Satoshi Nakaboto writes ab...
# 9   Opinions expressed by Entrepreneur contributor...
# 10  Bitcoin has always had the potential to become...
# 11  Our robot colleague Satoshi Nakaboto writes ab...
# 12  Our robot colleague Satoshi Nakaboto writes ab...
# 13  Our robot colleague Satoshi Nakaboto writes ab...
# 14  Our robot colleague Satoshi Nakaboto writes ab...
# 15  Our robot colleague Satoshi Nakaboto writes ab...
# 16  Our robot colleague Satoshi Nakaboto writes ab...
# 17  Our robot colleague Satoshi Nakaboto writes ab...
# 18  Our robot colleague Satoshi Nakaboto writes ab...
# 19  Our robot colleague Satoshi Nakaboto writes ab...

# %%
# Create the ethereum sentiment scores DataFrame
eth_sentiment_df = get_sentiment_score(eth_articles, 'content')
eth_sentiment_df
# Out:
#     Compound  Negative  Neutral  Positive  \
# 0     0.5070     0.000    0.910     0.090
# 1     0.0000     0.000    1.000     0.000
# 2     0.0000     0.000    1.000     0.000
# 3     0.6249     0.000    0.859     0.141
# 4    -0.4457     0.086    0.882     0.031
# 5     0.0000     0.148    0.703     0.148
# 6     0.0000     0.000    1.000     0.000
# 7     0.3400     0.050    0.861     0.089
# 8     0.5719     0.000    0.885     0.115
# 9     0.2732     0.000    0.943     0.057
# 10   -0.6705     0.143    0.857     0.000
# 11    0.5070     0.000    0.910     0.090
# 12    0.5070     0.000    0.910     0.090
# 13    0.0000     0.000    1.000     0.000
# 14    0.9198     0.000    0.665     0.335
# 15    0.3182     0.000    0.933     0.067
# 16   -0.2732     0.078    0.879     0.042
#
#                                               content
# 0   Our robot colleague Satoshi Nakaboto writes ab...
# 1   Editors note:Andreessen Horowitzs Crypto Start...
# 2   For developers looking to quickly build identi...
# 3   Use this to send Ether from one account to ano...
# 4   Some open-source groups, such as The Linux Fou...
# 5   With unemployment surging and businesses strug...
# 6   Over the last few weeks all eyes in the crypto...
# 7   Imagine sending $133 to a friend and being cha...
# 8   We have been looking for ways in which crypto ...
# 9   Back in March, we put out our call for ideas t...
# 10  Intel announced CrossTalk, a new side-channel ...
# 11  Our robot colleague Satoshi Nakaboto writes ab...
# 12  Our robot colleague Satoshi Nakaboto writes ab...
# 13  Bitcoin has always had the potential to become...
# 14  Blockchain technology is cementing its positio...
# 15  Opinions expressed by Entrepreneur contributor...
# 16  Opinions expressed by Entrepreneur contributor...

# %%
# Describe the Bitcoin Sentiment
btc_sentiment_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.312425   0.014100   0.913950   0.071850
# std     0.353454   0.036248   0.055201   0.053467
# min    -0.346400   0.000000   0.812000   0.000000
# 25%     0.000000   0.000000   0.910000   0.031500
# 50%     0.507000   0.000000   0.910000   0.090000
# 75%     0.507000   0.000000   0.915000   0.090000
# max     0.801600   0.134000   1.000000   0.188000

# %%
# Describe the Ethereum Sentiment\
eth_sentiment_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  17.000000  17.000000  17.000000  17.000000
# mean    0.187035   0.029706   0.893941   0.076176
# std     0.414909   0.052041   0.094435   0.083393
# min    -0.670500   0.000000   0.665000   0.000000
# 25%     0.000000   0.000000   0.861000   0.000000
# 50%     0.273200   0.000000   0.910000   0.067000
# 75%     0.507000   0.050000   0.943000   0.090000
# max     0.919800   0.148000   1.000000   0.335000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum - 0.919800
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum - 0.335

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Expand the default stopwords list if necessary
lemmatizer = WordNetLemmatizer()
sw = set(stopwords.words('english'))

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    # Remove the punctuation
    regex = re.compile("[^a-zA-Z0-9 ]")
    re_clean = regex.sub('', text)
    
    # Create a list of the words
    words = word_tokenize(re_clean.lower())
   
        
    # Convert the words to lowercase
    words = [word for word in words if word not in sw]
           
    # Lemmatize Words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
    return lem

tokenizer(btc_sentiment_df.iloc[0]['content'])
# Out:
# ['jk',
#  'rowling',
#  'drinking',
#  'lot',
#  'youd',
#  'better',
#  'believe',
#  'thought',
#  'bitcoinnotedterf',
#  'author',
#  'cuckoo',
#  'calling',
#  'rowlingdecided',
#  'friday',
#  'perfect',
#  'time',
#  'learn',
#  '2124',
#  'char']

# %%
# Create a new tokens column for bitcoin
btc_sentiment_df['tokens'] = btc_sentiment_df['content'].apply(tokenizer)
btc_sentiment_df
# Out:
#     Compound  Negative  Neutral  Positive  \
# 0     0.7650     0.000    0.829     0.171
# 1     0.0000     0.000    1.000     0.000
# 2     0.0000     0.000    1.000     0.000
# 3    -0.3464     0.134    0.819     0.046
# 4    -0.2755     0.070    0.930     0.000
# 5     0.0000     0.000    1.000     0.000
# 6     0.5070     0.000    0.910     0.090
# 7     0.8016     0.000    0.812     0.188
# 8     0.5070     0.000    0.910     0.090
# 9    -0.2732     0.078    0.879     0.042
# 10    0.0000     0.000    1.000     0.000
# 11    0.5070     0.000    0.910     0.090
# 12    0.5070     0.000    0.910     0.090
# 13    0.5070     0.000    0.910     0.090
# 14    0.5070     0.000    0.910     0.090
# 15    0.5070     0.000    0.910     0.090
# 16    0.5070     0.000    0.910     0.090
# 17    0.5070     0.000    0.910     0.090
# 18    0.5070     0.000    0.910     0.090
# 19    0.5070     0.000    0.910     0.090
#
#                                               content  \
# 0   J.K. Rowling has been drinking a lot and you'd...
# 1   The Winklevoss twinsthe brothers Mark Zuckerbe...
# 2   Over the last few weeks all eyes in the crypto...
# 3   If youre planning to do some protesting and yo...
# 4   Reuters\r\n<ul><li>Goldman Sachs gave five rea...
# 5   <ul><li>Famed investor Michael Novogratz tweet...
# 6   Our robot colleague Satoshi Nakaboto writes ab...
# 7   The move is the latest in a string of positive...
# 8   Our robot colleague Satoshi Nakaboto writes ab...
# 9   Opinions expressed by Entrepreneur contributor...
# 10  Bitcoin has always had the potential to become...
# 11  Our robot colleague Satoshi Nakaboto writes ab...
# 12  Our robot colleague Satoshi Nakaboto writes ab...
# 13  Our robot colleague Satoshi Nakaboto writes ab...
# 14  Our robot colleague Satoshi Nakaboto writes ab...
# 15  Our robot colleague Satoshi Nakaboto writes ab...
# 16  Our robot colleague Satoshi Nakaboto writes ab...
# 17  Our robot colleague Satoshi Nakaboto writes ab...
# 18  Our robot colleague Satoshi Nakaboto writes ab...
# 19  Our robot colleague Satoshi Nakaboto writes ab...
#
#                                                tokens
# 0   [jk, rowling, drinking, lot, youd, better, bel...
# 1   [winklevoss, twinsthe, brother, mark, zuckerbe...
# 2   [last, week, eye, crypto, world, glued, halven...
# 3   [youre, planning, protesting, dont, want, risk...
# 4   [reutersulligoldman, sachs, gave, five, reason...
# 5   [ullifamed, investor, michael, novogratz, twee...
# 6   [robot, colleague, satoshi, nakaboto, writes, ...
# 7   [move, latest, string, positive, development, ...
# 8   [robot, colleague, satoshi, nakaboto, writes, ...
# 9   [opinion, expressed, entrepreneur, contributor...
# 10  [bitcoin, always, potential, become, world, st...
# 11  [robot, colleague, satoshi, nakaboto, writes, ...
# 12  [robot, colleague, satoshi, nakaboto, writes, ...
# 13  [robot, colleague, satoshi, nakaboto, writes, ...
# 14  [robot, colleague, satoshi, nakaboto, writes, ...
# 15  [robot, colleague, satoshi, nakaboto, writes, ...
# 16  [robot, colleague, satoshi, nakaboto, writes, ...
# 17  [robot, colleague, satoshi, nakaboto, writes, ...
# 18  [robot, colleague, satoshi, nakaboto, writes, ...
# 19  [robot, colleague, satoshi, nakaboto, writes, ...

# %%
# Create a new tokens column for ethereum
eth_sentiment_df['tokens'] = eth_sentiment_df['content'].apply(tokenizer)
eth_sentiment_df
# Out:
#     Compound  Negative  Neutral  Positive  \
# 0     0.5070     0.000    0.910     0.090
# 1     0.0000     0.000    1.000     0.000
# 2     0.0000     0.000    1.000     0.000
# 3     0.6249     0.000    0.859     0.141
# 4    -0.4457     0.086    0.882     0.031
# 5     0.0000     0.148    0.703     0.148
# 6     0.0000     0.000    1.000     0.000
# 7     0.3400     0.050    0.861     0.089
# 8     0.5719     0.000    0.885     0.115
# 9     0.2732     0.000    0.943     0.057
# 10   -0.6705     0.143    0.857     0.000
# 11    0.5070     0.000    0.910     0.090
# 12    0.5070     0.000    0.910     0.090
# 13    0.0000     0.000    1.000     0.000
# 14    0.9198     0.000    0.665     0.335
# 15    0.3182     0.000    0.933     0.067
# 16   -0.2732     0.078    0.879     0.042
#
#                                               content  \
# 0   Our robot colleague Satoshi Nakaboto writes ab...
# 1   Editors note:Andreessen Horowitzs Crypto Start...
# 2   For developers looking to quickly build identi...
# 3   Use this to send Ether from one account to ano...
# 4   Some open-source groups, such as The Linux Fou...
# 5   With unemployment surging and businesses strug...
# 6   Over the last few weeks all eyes in the crypto...
# 7   Imagine sending $133 to a friend and being cha...
# 8   We have been looking for ways in which crypto ...
# 9   Back in March, we put out our call for ideas t...
# 10  Intel announced CrossTalk, a new side-channel ...
# 11  Our robot colleague Satoshi Nakaboto writes ab...
# 12  Our robot colleague Satoshi Nakaboto writes ab...
# 13  Bitcoin has always had the potential to become...
# 14  Blockchain technology is cementing its positio...
# 15  Opinions expressed by Entrepreneur contributor...
# 16  Opinions expressed by Entrepreneur contributor...
#
#                                                tokens
# 0   [robot, colleague, satoshi, nakaboto, writes, ...
# 1   [editor, noteandreessen, horowitz, crypto, sta...
# 2   [developer, looking, quickly, build, identity,...
# 3   [use, send, ether, one, account, another, smar...
# 4   [opensource, group, linux, foundation, deal, o...
# 5   [unemployment, surging, business, struggling, ...
# 6   [last, week, eye, crypto, world, glued, halven...
# 7   [imagine, sending, 133, friend, charged, 25, m...
# 8   [looking, way, crypto, asset, go, mainstream, ...
# 9   [back, march, put, call, idea, fixtheinternet,...
# 10  [intel, announced, crosstalk, new, sidechannel...
# 11  [robot, colleague, satoshi, nakaboto, writes, ...
# 12  [robot, colleague, satoshi, nakaboto, writes, ...
# 13  [bitcoin, always, potential, become, world, st...
# 14  [blockchain, technology, cementing, position, ...
# 15  [opinion, expressed, entrepreneur, contributor...
# 16  [opinion, expressed, entrepreneur, contributor...

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
def get_token(df):
    tokens = []
    for i in df['tokens']:
        tokens.extend(i)
    return tokens

btc_tokens = get_token(btc_sentiment_df)
eth_tokens = get_token(eth_sentiment_df)

# %%
# Generate the Bitcoin N-grams where N=2
def bigram_counter(tokens, N):
    words_count = dict(Counter(ngrams(tokens, n=N)))
    return words_count

# %%
bigram_btc = bigram_counter(btc_tokens, 2)
bigram_btc
# Out:
# {('jk', 'rowling'): 1,
#  ('rowling', 'drinking'): 1,
#  ('drinking', 'lot'): 1,
#  ('lot', 'youd'): 1,
#  ('youd', 'better'): 1,
#  ('better', 'believe'): 1,
#  ('believe', 'thought'): 1,
#  ('thought', 'bitcoinnotedterf'): 1,
#  ('bitcoinnotedterf', 'author'): 1,
#  ('author', 'cuckoo'): 1,
#  ('cuckoo', 'calling'): 1,
#  ('calling', 'rowlingdecided'): 1,
#  ('rowlingdecided', 'friday'): 1,
#  ('friday', 'perfect'): 1,
#  ('perfect', 'time'): 1,
#  ('time', 'learn'): 1,
#  ('learn', '2124'): 1,
#  ('2124', 'char'): 1,
#  ('char', 'winklevoss'): 1,
#  ('winklevoss', 'twinsthe'): 1,
#  ('twinsthe', 'brother'): 1,
#  ('brother', 'mark'): 1,
#  ('mark', 'zuckerberg'): 1,
#  ('zuckerberg', 'allegedly'): 1,
#  ('allegedly', 'stole'): 1,
#  ('stole', 'idea'): 1,
#  ('idea', 'facebook'): 1,
#  ('facebook', 'fromare'): 1,
#  ('fromare', 'making'): 1,
#  ('making', 'movie'): 1,
#  ('movie', 'deadline'): 1,
#  ('deadline', 'reported'): 1,
#  ('reported', 'week'): 1,
#  ('week', 'doesnt'): 1,
#  ('doesnt', 'seem'): 1,
#  ('seem', 'masturbatory'): 1,
#  ('masturbatory', 'enough'): 1,
#  ('enough', 'r'): 1,
#  ('r', '2657'): 1,
#  ('2657', 'char'): 1,
#  ('char', 'last'): 1,
#  ('last', 'week'): 1,
#  ('week', 'eye'): 1,
#  ('eye', 'crypto'): 1,
#  ('crypto', 'world'): 1,
#  ('world', 'glued'): 1,
#  ('glued', 'halvening'): 1,
#  ('halvening', 'nighreligious'): 1,
#  ('nighreligious', 'moment'): 1,
#  ('moment', 'blockchain'): 1,
#  ('blockchain', 'realm'): 1,
#  ('realm', 'every'): 1,
#  ('every', 'amount'): 1,
#  ('amount', 'new'): 1,
#  ('new', 'bitcoin'): 1,
#  ('bitcoin', 'mined'): 1,
#  ('mined', 'distri'): 1,
#  ('distri', '4849'): 1,
#  ('4849', 'char'): 1,
#  ('char', 'youre'): 1,
#  ('youre', 'planning'): 1,
#  ('planning', 'protesting'): 1,
#  ('protesting', 'dont'): 1,
#  ('dont', 'want'): 1,
#  ('want', 'risk'): 1,
#  ('risk', 'expensive'): 1,
#  ('expensive', 'smartphone'): 1,
#  ('smartphone', 'processor'): 1,
#  ('processor', 'simply'): 1,
#  ('simply', 'want'): 1,
#  ('want', 'keep'): 1,
#  ('keep', 'anonymous'): 1,
#  ('anonymous', 'possible'): 1,
#  ('possible', 'youre'): 1,
#  ('youre', 'outconsider'): 1,
#  ('outconsider', 'buying'): 1,
#  ('buying', '5568'): 1,
#  ('5568', 'char'): 1,
#  ('char', 'reutersulligoldman'): 1,
#  ('reutersulligoldman', 'sachs'): 1,
#  ('sachs', 'gave'): 1,
#  ('gave', 'five'): 1,
#  ('five', 'reason'): 1,
#  ('reason', 'think'): 1,
#  ('think', 'bitcoin'): 1,
#  ('bitcoin', 'asset'): 1,
#  ('asset', 'class'): 1,
#  ('class', 'suitable'): 1,
#  ('suitable', 'investment'): 1,
#  ('investment', 'presentation'): 1,
#  ('presentation', 'wednesday'): 1,
#  ('wednesday', 'morningliligoldman'): 1,
#  ('morningliligoldman', 'observed'): 1,
#  ('observed', 'crypt'): 1,
#  ('crypt', '3412'): 1,
#  ('3412', 'char'): 1,
#  ('char', 'ullifamed'): 1,
#  ('ullifamed', 'investor'): 1,
#  ('investor', 'michael'): 1,
#  ('michael', 'novogratz'): 1,
#  ('novogratz', 'tweeted'): 1,
#  ('tweeted', 'monday'): 1,
#  ('monday', 'bitcoin'): 1,
#  ('bitcoin', 'soon'): 1,
#  ('soon', 'take'): 1,
#  ('take', '10000'): 1,
#  ('10000', 'resistance'): 1,
#  ('resistance', 'level'): 1,
#  ('level', 'telling'): 1,
#  ('telling', 'follower'): 1,
#  ('follower', 'get'): 1,
#  ('get', 'trainlilinovogratz'): 1,
#  ('trainlilinovogratz', 'said'): 1,
#  ('said', 'turmoil'): 1,
#  ('turmoil', '2757'): 1,
#  ('2757', 'char'): 1,
#  ('char', 'robot'): 11,
#  ('robot', 'colleague'): 11,
#  ('colleague', 'satoshi'): 11,
#  ('satoshi', 'nakaboto'): 22,
#  ('nakaboto', 'writes'): 11,
#  ('writes', 'bitcoin'): 11,
#  ('bitcoin', 'btc'): 10,
#  ('btc', 'every'): 10,
#  ('every', 'fucking'): 11,
#  ('fucking', 'daywelcome'): 11,
#  ('daywelcome', 'another'): 11,
#  ('another', 'edition'): 11,
#  ('edition', 'bitcoin'): 11,
#  ('bitcoin', 'today'): 11,
#  ('today', 'satoshi'): 11,
#  ('nakaboto', 'tell'): 11,
#  ('tell', 'whats'): 11,
#  ('whats', 'going'): 11,
#  ('going', 'bitcoin'): 11,
#  ('bitcoin', '3004'): 1,
#  ('3004', 'char'): 1,
#  ('char', 'move'): 1,
#  ('move', 'latest'): 1,
#  ('latest', 'string'): 1,
#  ('string', 'positive'): 1,
#  ('positive', 'development'): 1,
#  ('development', 'bitcoin'): 1,
#  ('bitcoin', 'another'): 1,
#  ('another', 'sign'): 1,
#  ('sign', 'wall'): 1,
#  ('wall', 'street'): 1,
#  ('street', 'becoming'): 1,
#  ('becoming', 'comfortable'): 1,
#  ('comfortable', 'business'): 1,
#  ('business', 'cryptocurrencies'): 1,
#  ('cryptocurrencies', 'coinbase'): 1,
#  ('coinbase', 'founded'): 1,
#  ('founded', '2012'): 1,
#  ('2012', '1067'): 1,
#  ('1067', 'char'): 1,
#  ('bitcoin', 'every'): 1,
#  ('bitcoin', '3041'): 1,
#  ('3041', 'char'): 1,
#  ('char', 'opinion'): 1,
#  ('opinion', 'expressed'): 1,
#  ('expressed', 'entrepreneur'): 1,
#  ('entrepreneur', 'contributor'): 1,
#  ('contributor', 'owndespite'): 1,
#  ('owndespite', 'recent'): 1,
#  ('recent', 'price'): 1,
#  ('price', 'volatilityand'): 1,
#  ('volatilityand', 'global'): 1,
#  ('global', 'macroeconomic'): 1,
#  ('macroeconomic', 'uncertainty'): 1,
#  ('uncertainty', '2020'): 1,
#  ('2020', 'big'): 1,
#  ('big', 'year'): 1,
#  ('year', 'bitcoin'): 1,
#  ('bitcoin', 'although'): 1,
#  ('although', 'large'): 1,
#  ('large', 'number'): 1,
#  ('number', 'busine'): 1,
#  ('busine', '6168'): 1,
#  ('6168', 'char'): 1,
#  ('char', 'bitcoin'): 1,
#  ('bitcoin', 'always'): 1,
#  ('always', 'potential'): 1,
#  ('potential', 'become'): 1,
#  ('become', 'world'): 1,
#  ('world', 'standard'): 1,
#  ('standard', 'money'): 1,
#  ('money', 'even'): 1,
#  ('even', 'blockchain'): 1,
#  ('blockchain', 'power'): 1,
#  ('power', 'bitcoin'): 1,
#  ('bitcoin', 'lack'): 1,
#  ('lack', 'bandwidth'): 1,
#  ('bandwidth', 'handle'): 1,
#  ('handle', 'required'): 1,
#  ('required', 'transaction'): 1,
#  ('transaction', 'volume'): 1,
#  ('volume', 'even'): 1,
#  ('even', 'wo'): 1,
#  ('wo', '9396'): 1,
#  ('9396', 'char'): 1,
#  ('bitcoin', '3009'): 1,
#  ('3009', 'char'): 1,
#  ('bitcoin', '2941'): 1,
#  ('2941', 'char'): 1,
#  ('bitcoin', '2953'): 1,
#  ('2953', 'char'): 1,
#  ('bitcoin', '3087'): 1,
#  ('3087', 'char'): 1,
#  ('bitcoin', '3328'): 1,
#  ('3328', 'char'): 1,
#  ('bitcoin', '3034'): 1,
#  ('3034', 'char'): 1,
#  ('bitcoin', '3263'): 1,
#  ('3263', 'char'): 1,
#  ('bitcoin', '3070'): 1,
#  ('3070', 'char'): 1,
#  ('bitcoin', '2940'): 1,
#  ('2940', 'char'): 1}

# %%
# Generate the Ethereum N-grams where N=2
bigram_eth = bigram_counter(eth_tokens, 2)
bigram_eth
# Out:
# {('robot', 'colleague'): 3,
#  ('colleague', 'satoshi'): 3,
#  ('satoshi', 'nakaboto'): 6,
#  ('nakaboto', 'writes'): 3,
#  ('writes', 'bitcoin'): 3,
#  ('bitcoin', 'btc'): 3,
#  ('btc', 'every'): 3,
#  ('every', 'fucking'): 3,
#  ('fucking', 'daywelcome'): 3,
#  ('daywelcome', 'another'): 3,
#  ('another', 'edition'): 3,
#  ('edition', 'bitcoin'): 3,
#  ('bitcoin', 'today'): 3,
#  ('today', 'satoshi'): 3,
#  ('nakaboto', 'tell'): 3,
#  ('tell', 'whats'): 3,
#  ('whats', 'going'): 3,
#  ('going', 'bitcoin'): 3,
#  ('bitcoin', '3095'): 1,
#  ('3095', 'char'): 1,
#  ('char', 'editor'): 1,
#  ('editor', 'noteandreessen'): 1,
#  ('noteandreessen', 'horowitz'): 1,
#  ('horowitz', 'crypto'): 1,
#  ('crypto', 'startup'): 1,
#  ('startup', 'school'): 1,
#  ('school', 'brought'): 1,
#  ('brought', 'together'): 1,
#  ('together', '45'): 1,
#  ('45', 'participant'): 1,
#  ('participant', 'around'): 1,
#  ('around', 'u'): 1,
#  ('u', 'overseas'): 1,
#  ('overseas', 'sevenweek'): 1,
#  ('sevenweek', 'course'): 1,
#  ('course', 'learn'): 1,
#  ('learn', 'build'): 1,
#  ('build', 'crypto'): 1,
#  ('crypto', 'company'): 1,
#  ('company', 'andreessen'): 1,
#  ('andreessen', 'ho'): 1,
#  ('ho', '2503'): 1,
#  ('2503', 'char'): 1,
#  ('char', 'developer'): 1,
#  ('developer', 'looking'): 1,
#  ('looking', 'quickly'): 1,
#  ('quickly', 'build'): 1,
#  ('build', 'identity'): 1,
#  ('identity', 'management'): 1,
#  ('management', 'platform'): 1,
#  ('platform', 'readily'): 1,
#  ('readily', 'available'): 1,
#  ('available', 'option'): 1,
#  ('option', 'dont'): 1,
#  ('dont', 'stray'): 1,
#  ('stray', 'far'): 1,
#  ('far', 'internet'): 1,
#  ('internet', 'biggest'): 1,
#  ('biggest', 'datahungry'): 1,
#  ('datahungry', 'platformsmagic'): 1,
#  ('platformsmagic', '2450'): 1,
#  ('2450', 'char'): 1,
#  ('char', 'use'): 1,
#  ('use', 'send'): 1,
#  ('send', 'ether'): 1,
#  ('ether', 'one'): 1,
#  ('one', 'account'): 1,
#  ('account', 'another'): 1,
#  ('another', 'smart'): 1,
#  ('smart', 'contract'): 1,
#  ('contract', 'address'): 1,
#  ('address', 'requires'): 1,
#  ('requires', 'parameter'): 1,
#  ('parameter', 'depending'): 1,
#  ('depending', 'transaction'): 1,
#  ('transaction', 'possible'): 1,
#  ('possible', 'parameter'): 1,
#  ('parameter', 'include'): 1,
#  ('include', 'value'): 1,
#  ('value', 'gas'): 1,
#  ('gas', '206'): 1,
#  ('206', 'char'): 1,
#  ('char', 'opensource'): 1,
#  ('opensource', 'group'): 1,
#  ('group', 'linux'): 1,
#  ('linux', 'foundation'): 1,
#  ('foundation', 'deal'): 1,
#  ('deal', 'others'): 1,
#  ('others', 'arent'): 1,
#  ('arent', 'fortunate'): 1,
#  ('fortunate', 'drupal'): 1,
#  ('drupal', 'foundation'): 1,
#  ('foundation', 'open'): 1,
#  ('open', 'source'): 2,
#  ('source', 'initiative'): 1,
#  ('initiative', 'osi'): 1,
#  ('osi', 'open'): 1,
#  ('source', 'matter'): 1,
#  ('matter', 'joomla'): 1,
#  ('joomla', '1202'): 1,
#  ('1202', 'char'): 1,
#  ('char', 'unemployment'): 1,
#  ('unemployment', 'surging'): 1,
#  ('surging', 'business'): 1,
#  ('business', 'struggling'): 1,
#  ('struggling', 'lockdown'): 1,
#  ('lockdown', 'million'): 1,
#  ('million', 'american'): 1,
#  ('american', 'relying'): 1,
#  ('relying', 'extra'): 1,
#  ('extra', 'benefit'): 1,
#  ('benefit', 'payment'): 1,
#  ('payment', 'issued'): 1,
#  ('issued', '2'): 1,
#  ('2', 'trillion'): 1,
#  ('trillion', 'dollar'): 1,
#  ('dollar', 'coronavirus'): 1,
#  ('coronavirus', 'aid'): 1,
#  ('aid', 'relief'): 1,
#  ('relief', 'ec'): 1,
#  ('ec', '5094'): 1,
#  ('5094', 'char'): 1,
#  ('char', 'last'): 1,
#  ('last', 'week'): 1,
#  ('week', 'eye'): 1,
#  ('eye', 'crypto'): 1,
#  ('crypto', 'world'): 1,
#  ('world', 'glued'): 1,
#  ('glued', 'halvening'): 1,
#  ('halvening', 'nighreligious'): 1,
#  ('nighreligious', 'moment'): 1,
#  ('moment', 'blockchain'): 1,
#  ('blockchain', 'realm'): 1,
#  ('realm', 'every'): 1,
#  ('every', 'amount'): 1,
#  ('amount', 'new'): 1,
#  ('new', 'bitcoin'): 1,
#  ('bitcoin', 'mined'): 1,
#  ('mined', 'distri'): 1,
#  ('distri', '4849'): 1,
#  ('4849', 'char'): 1,
#  ('char', 'imagine'): 1,
#  ('imagine', 'sending'): 1,
#  ('sending', '133'): 1,
#  ('133', 'friend'): 1,
#  ('friend', 'charged'): 1,
#  ('charged', '25'): 1,
#  ('25', 'million'): 2,
#  ('million', 'fee'): 1,
#  ('fee', 'seems'): 1,
#  ('seems', 'case'): 1,
#  ('case', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'user'): 1,
#  ('user', 'paid'): 1,
#  ('paid', '25'): 1,
#  ('million', 'transaction'): 1,
#  ('transaction', 'fee'): 1,
#  ('fee', 'trade'): 1,
#  ('trade', 'wednesday'): 1,
#  ('wednesday', 'morning'): 1,
#  ('morning', '2684'): 1,
#  ('2684', 'char'): 1,
#  ('char', 'looking'): 1,
#  ('looking', 'way'): 1,
#  ('way', 'crypto'): 1,
#  ('crypto', 'asset'): 1,
#  ('asset', 'go'): 1,
#  ('go', 'mainstream'): 1,
#  ('mainstream', 'interest'): 1,
#  ('interest', 'investment'): 1,
#  ('investment', 'dappers'): 1,
#  ('dappers', 'crypto'): 1,
#  ('crypto', 'game'): 1,
#  ('game', 'effort'): 1,
#  ('effort', 'area'): 1,
#  ('area', 'involvement'): 1,
#  ('involvement', 'libra'): 1,
#  ('libra', 'project'): 1,
#  ('project', 'w'): 1,
#  ('w', '1743'): 1,
#  ('1743', 'char'): 1,
#  ('char', 'back'): 1,
#  ('back', 'march'): 1,
#  ('march', 'put'): 1,
#  ('put', 'call'): 1,
#  ('call', 'idea'): 1,
#  ('idea', 'fixtheinternet'): 1,
#  ('fixtheinternet', '1500'): 1,
#  ('1500', 'showed'): 1,
#  ('showed', 'well'): 1,
#  ('well', 'hundred'): 1,
#  ('hundred', 'project'): 1,
#  ('project', 'underway'): 1,
#  ('underway', 'launching'): 1,
#  ('launching', 'v2'): 1,
#  ('v2', 'mozilla'): 1,
#  ('mozilla', 'builder'): 1,
#  ('builder', 'incubator'): 1,
#  ('incubator', '469'): 1,
#  ('469', 'char'): 1,
#  ('char', 'intel'): 1,
#  ('intel', 'announced'): 1,
#  ('announced', 'crosstalk'): 1,
#  ('crosstalk', 'new'): 1,
#  ('new', 'sidechannel'): 1,
#  ('sidechannel', 'attack'): 1,
#  ('attack', 'leak'): 1,
#  ('leak', 'data'): 1,
#  ('data', 'cpu'): 1,
#  ('cpu', 'buffer'): 1,
#  ('buffer', 'story'): 1,
#  ('story', 'weve'): 1,
#  ('weve', 'heard'): 1,
#  ('heard', 'bit'): 1,
#  ('bit', 'internal'): 1,
#  ('internal', 'cpu'): 1,
#  ('cpu', 'state'): 1,
#  ('state', 'inferred'): 1,
#  ('inferred', 'process'): 1,
#  ('process', '5744'): 1,
#  ('5744', 'char'): 1,
#  ('char', 'robot'): 2,
#  ('bitcoin', '3087'): 1,
#  ('3087', 'char'): 1,
#  ('bitcoin', '3070'): 1,
#  ('3070', 'char'): 1,
#  ('char', 'bitcoin'): 1,
#  ('bitcoin', 'always'): 1,
#  ('always', 'potential'): 1,
#  ('potential', 'become'): 1,
#  ('become', 'world'): 1,
#  ('world', 'standard'): 1,
#  ('standard', 'money'): 1,
#  ('money', 'even'): 1,
#  ('even', 'blockchain'): 1,
#  ('blockchain', 'power'): 1,
#  ('power', 'bitcoin'): 1,
#  ('bitcoin', 'lack'): 1,
#  ('lack', 'bandwidth'): 1,
#  ('bandwidth', 'handle'): 1,
#  ('handle', 'required'): 1,
#  ('required', 'transaction'): 1,
#  ('transaction', 'volume'): 1,
#  ('volume', 'even'): 1,
#  ('even', 'wo'): 1,
#  ('wo', '9396'): 1,
#  ('9396', 'char'): 1,
#  ('char', 'blockchain'): 1,
#  ('blockchain', 'technology'): 1,
#  ('technology', 'cementing'): 1,
#  ('cementing', 'position'): 1,
#  ('position', 'business'): 1,
#  ('business', 'marketplace'): 1,
#  ('marketplace', 'help'): 1,
#  ('help', 'get'): 1,
#  ('get', 'customer'): 1,
#  ('customer', 'gratefully'): 1,
#  ('gratefully', 'first'): 1,
#  ('first', 'thing'): 1,
#  ('thing', 'blockchain'): 1,
#  ('blockchain', 'help'): 1,
#  ('help', 'better'): 1,
#  ('better', 'security'): 1,
#  ('security', 'goi'): 1,
#  ('goi', '9561'): 1,
#  ('9561', 'char'): 1,
#  ('char', 'opinion'): 2,
#  ('opinion', 'expressed'): 2,
#  ('expressed', 'entrepreneur'): 2,
#  ('entrepreneur', 'contributor'): 2,
#  ('contributor', 'owncalling'): 1,
#  ('owncalling', 'millennialshow'): 1,
#  ('millennialshow', 'much'): 1,
#  ('much', 'money'): 1,
#  ('money', 'equityor'): 1,
#  ('equityor', 'invested'): 1,
#  ('invested', 'somewhere'): 1,
#  ('somewhere', 'sure'): 1,
#  ('sure', 'may'): 1,
#  ('may', 'saving'): 1,
#  ('saving', 'account'): 1,
#  ('account', 'mutual'): 1,
#  ('mutual', 'fu'): 1,
#  ('fu', '4116'): 1,
#  ('4116', 'char'): 1,
#  ('contributor', 'owndespite'): 1,
#  ('owndespite', 'recent'): 1,
#  ('recent', 'price'): 1,
#  ('price', 'volatilityand'): 1,
#  ('volatilityand', 'global'): 1,
#  ('global', 'macroeconomic'): 1,
#  ('macroeconomic', 'uncertainty'): 1,
#  ('uncertainty', '2020'): 1,
#  ('2020', 'big'): 1,
#  ('big', 'year'): 1,
#  ('year', 'bitcoin'): 1,
#  ('bitcoin', 'although'): 1,
#  ('although', 'large'): 1,
#  ('large', 'number'): 1,
#  ('number', 'busine'): 1,
#  ('busine', '6168'): 1,
#  ('6168', 'char'): 1}

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin
token_count(btc_tokens, 10)
# Out:
# [('bitcoin', 40),
#  ('satoshi', 22),
#  ('nakaboto', 22),
#  ('char', 20),
#  ('every', 12),
#  ('another', 12),
#  ('robot', 11),
#  ('colleague', 11),
#  ('writes', 11),
#  ('fucking', 11)]

# %%
# Get the top 10 words for Ethereum
token_count(eth_tokens, 10)
# Out:
# [('char', 17),
#  ('bitcoin', 13),
#  ('satoshi', 6),
#  ('nakaboto', 6),
#  ('crypto', 5),
#  ('every', 4),
#  ('another', 4),
#  ('blockchain', 4),
#  ('robot', 3),
#  ('colleague', 3)]

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [15.0,10.0]

# %%
# Generate the Bitcoin word cloud
wc = WordCloud().generate(' '.join(btc_tokens))
plt.title("Bitcoin Word Cloud", fontsize = 50, fontweight = 'bold')
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
wc = WordCloud().generate(' '.join(eth_tokens))
plt.title("Ethereum Word Cloud", fontsize = 50, fontweight = 'bold')
plt.imshow(wc)

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Optional - download a language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
btc_content = ' '.join(btc_sentiment_df['content'])
btc_content
# Out:
# 'J.K. Rowling has been drinking a lot and you\'d better believe she has some thoughts on Bitcoin.\r\nNotedTERF and author of The Cuckoos Calling, Rowlingdecided Friday was the perfect time to learn about… [+2124 chars] The Winklevoss twinsthe brothers Mark Zuckerberg allegedly stole the idea for Facebook fromare making a movie about themselves, Deadline reported this week. If that doesnt seem masturbatory enough, r… [+2657 chars] Over the last few weeks all eyes in the crypto world have been glued to the halvening, a nigh-religious moment in the blockchain realm. Every once in a while, the amount of new bitcoin mined — distri… [+4849 chars] If youre planning to do some protesting and you dont want to risk your expensive smartphone in the processor you simply want to keep yourself as anonymous as possible while youre outconsider buying a… [+5568 chars] Reuters\r\n<ul><li>Goldman Sachs gave five reasons why it thinks bitcoin is "not an asset class" nor "a suitable investment" in a presentation Wednesday morning.</li><li>Goldman observed that the crypt… [+3412 chars] <ul><li>Famed investor Michael Novogratz tweeted on Monday that bitcoin will soon take out the $10,000 resistance level, telling his followers, "Get on the train."</li><li>Novogratz said that turmoil… [+2757 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3004 chars] The move is the latest in a string of positive developments for bitcoin and another sign that Wall Street is becoming more comfortable with the business of cryptocurrencies. Coinbase, founded in 2012… [+1067 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the … [+3041 chars] Opinions expressed by Entrepreneur contributors are their own.\r\nDespite recent price volatility\xa0and global macroeconomic uncertainty, 2020 is a big year for Bitcoin. Although a large number of busine… [+6168 chars] Bitcoin has always had the potential to become a world standard for money. Even if the blockchain that powers Bitcoin lacks the bandwidth to handle the required transaction volume, and even if the wo… [+9396 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3009 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2941 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2953 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3087 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3328 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3034 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3263 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to anothe ...

# %%
# Run the NER processor on all of the text
doc = nlp(btc_content)

# Add a title to the document
doc.user_data["title"] = "BITCOIN NER"

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <h2 style="margin: 0">BITCOIN NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     J.K. Rowling
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has been drinking a lot and you'd better believe she has some thoughts on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>NotedTERF and author of
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Cuckoos Calling
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# , Rowlingdecided
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  was the perfect time to learn about… [+2124 chars]
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Winklevoss
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  twinsthe brothers
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mark Zuckerberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  allegedly stole the idea for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Facebook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  fromare making a movie about themselves,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deadline
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  reported
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . If that doesnt seem masturbatory enough, r… [
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     +2657
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  chars] Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last few weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  all eyes in the crypto world have been glued to the halvening, a nigh-religious moment in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     blockchain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  realm. Every once in a while, the amount of
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  mined — distri… [+4849 chars] If youre planning to do some protesting and you dont want to risk your expensive smartphone in the processor you simply want to keep yourself as anonymous as possible while youre outconsider buying a… [+5568 chars]
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# &lt;ul&gt;&lt;li&gt;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Goldman Sachs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  gave
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     five
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  reasons why it thinks
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is &quot;not an asset class&quot; nor &quot;a suitable investment&quot; in a presentation
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  morning.&lt;/li&gt;&lt;li&gt;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Goldman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  observed that the crypt… [+3412 chars] &lt;ul&gt;&lt;li&gt;Famed investor
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michael Novogratz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  tweeted on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppe

# %%
# List all Entities
for ent in doc.ents:
    print('{} {}'.format(ent.text, ent.label_))
# Out:
# J.K. Rowling PERSON
# Bitcoin GPE
# The Cuckoos Calling WORK_OF_ART
# Friday DATE
# The Winklevoss WORK_OF_ART
# Mark Zuckerberg PERSON
# Facebook ORG
# Deadline PERSON
# this week DATE
# +2657 ORG
# the last few weeks DATE
# blockchain GPE
# new bitcoin LOC
# Reuters
#  ORG
# Goldman Sachs ORG
# five CARDINAL
# bitcoin GPE
# Wednesday DATE
# Goldman ORG
# Michael Novogratz PERSON
# Monday DATE
# bitcoin GPE
# $10,000 resistance MONEY
# Novogratz PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# bitcoin GPE
# 2012 DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# 2020 DATE
# a big year DATE
# Bitcoin GPE
# Bitcoin GPE
# Bitcoin PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the bitcoin text together
eth_content = ' '.join(eth_sentiment_df['content'])
eth_content
# Out:
# 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3095 chars] Editors note:Andreessen Horowitzs Crypto Startup School brought together 45 participants from around the U.S. and overseas in a seven-week course to learn how to build crypto companies. Andreessen Ho… [+2503 chars] For developers looking to quickly build identity management into their platforms, the most readily available options don’t stray far from the internet’s biggest, most data-hungry platforms.\r\nMagic, a… [+2450 chars] Use this to send Ether from one account to another or a smart contract address. It requires a few parameters depending on the transaction. Possible parameters include from, to, value, gas, and more.\r… [+206 chars] Some open-source groups, such as The Linux Foundation, can deal with it. Others aren\'t so fortunate. Some, such as Drupal Foundation, the Open Source Initiative (OSI), Open Source Matters (Joomla), a… [+1202 chars] With unemployment surging and businesses struggling under lockdown, millions of Americans are relying on the extra benefits payments issued under the $2 trillion dollar Coronavirus Aid, Relief and Ec… [+5094 chars] Over the last few weeks all eyes in the crypto world have been glued to the halvening, a nigh-religious moment in the blockchain realm. Every once in a while, the amount of new bitcoin mined — distri… [+4849 chars] Imagine sending $133 to a friend and being charged a $2.5 million fee. That seems to be the case for a cryptocurrency user who paid a $2.5 million transaction fee during a trade on Wednesday morning … [+2684 chars] We have been looking for ways in which crypto assets can go mainstream. Our interest and investment in Dapper’s crypto games is an effort in that area. So is our involvement in the Libra project. \r\nW… [+1743 chars] Back in March, we put out our call for ideas to "fix-the-internet". 1500 of you showed up and well over a hundred projects are now underway. Now we\'re launching our v2: the Mozilla Builders Incubator… [+469 chars] Intel announced CrossTalk, a new side-channel attack that can leak data from CPU buffers. It’s the same story we’ve heard before. Bits of internal CPU state can be inferred by other processes. This a… [+5744 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3087 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3070 chars] Bitcoin has always had the potential to become a world standard for money. Even if the blockchain that powers Bitcoin lacks the bandwidth to handle the required transaction volume, and even if the wo… [+9396 chars] Blockchain technology is cementing its position in the business marketplace to help you get more customers. Gratefully, the first thing that blockchain will help with is better security. But it’s goi… [+9561 chars] Opinions expressed by Entrepreneur contributors are their own.\r\nCalling all millennials:\xa0How much of your money is in equity\xa0or invested somewhere? Sure, there may be a savings account in a mutual fu… [+4116 chars] Opinions expressed by Entrepreneur contributors are their own.\r\nDespite recent price volatility\xa0and global macroeconomic uncertainty, 2020 is a big year for Bitcoin. Although a large number of busine… [+6168 chars]'

# %%
# Run the NER processor on all of the text
doc = nlp(eth_content)

# Add a title to the document
doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Our robot colleague
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Satoshi Nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  writes about
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>Welcome to another edition of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , where I,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Satoshi Nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , tell you whats been going on with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in … [+3095 chars] Editors note:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Andreessen Horowitzs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crypto Startup School
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  brought together
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     45
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  participants from around the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and overseas in a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seven-week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  course to learn how to build crypto companies.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Andreessen Ho
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Magic, a… [+2450 chars] Use this to send
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ether
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# … [+206 chars] Some open-source groups, such as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Linux Foundation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , can deal with it. Others aren't so fortunate. Some, such as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Drupal Foundation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the Open Source Initiative (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OSI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ), Open Source Matters (Joomla), a… [+1202 chars] With unemployment surging and businesses struggling under lockdown,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     millions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  are relying on the extra benefits payments issued under the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $2 trillion dollar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  Coronavirus Aid,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Relief
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ec
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# … [+5094 chars] Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last few weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-r

# %%
# List all Entities
for ent in doc.ents:
    print('{} {}'.format(ent.text, ent.label_))
# Out:
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Andreessen Horowitzs ORG
# Crypto Startup School ORG
# 45 CARDINAL
# U.S. GPE
# seven-week DATE
# Andreessen Ho PERSON
# Ether PERSON
# The Linux Foundation ORG
# Drupal Foundation ORG
# OSI ORG
# millions CARDINAL
# Americans NORP
# $2 trillion dollar MONEY
# Relief ORG
# Ec ORG
# the last few weeks DATE
# blockchain GPE
# new bitcoin LOC
# 133 MONEY
# $2.5 million MONEY
# $2.5 million MONEY
# Wednesday DATE
# morning TIME
# Dapper ORG
# Libra GPE
# March DATE
# 1500 CARDINAL
# well over a hundred CARDINAL
# the Mozilla Builders Incubator ORG
# Intel ORG
# CrossTalk ORG
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Bitcoin PERSON
# Blockchain GPE
# first ORDINAL
# blockchain GPE
# 2020 DATE
# a big year DATE
# Bitcoin GPE
